# %% [markdown]
# #  Consignes
#
# ## Description
#
# Ouvrir le fichier ks-projects-201801.csv, il recense environ 100 000 projets KickStarter. Intégrer les données directement avec L'API Python dans une base de données Mongo.
#
# Il conviendra de bien spécifier manuellement l'ID du document. Pensez aussi à bien formatter le type des données pour profiter des méthodes implémentées par Mongo. L'ensemble de données n'est pas forcément nécessaire, c'est à vous de créer votre modèle de données.
#
# ## Questions
#
# - 1) Récupérer les 5 projets ayant reçu le plus de promesse de dons.
# - 2) Compter le nombre de projets ayant atteint leur but.
# - 3) Compter le nombre de projets pour chaque catégorie.
# - 4) Compter le nombre de projets français ayant été instanciés avant 2016.
# - 5) Récupérer les projets américains ayant demandé plus de 200 000 dollars.
# - 6) Compter le nombre de projet ayant "Sport" dans leur nom

# %%
# !pip install 'pymongo[srv]'
# Out:
# Requirement already satisfied: pymongo[srv] in /root/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.6/site-packages (3.5.1)
# WARNING: pymongo 3.5.1 does not provide the extra 'srv'

# %%
import pandas as pd
import pymongo

# %%
# client = pymongo.MongoClient("mongodb://dbUser:aTerribleSecret@cluster0-shard-00-00.nxr70.mongodb.net:27017,cluster0-shard-00-01.nxr70.mongodb.net:27017,cluster0-shard-00-02.nxr70.mongodb.net:27017/?ssl=true&authMechanism=SCRAM-SHA-1")
client = pymongo.MongoClient("mongo")
database = client['exercices']
collection = database['kickstarter']

serverStatusResult = database.command("serverStatus")
print(serverStatusResult)
# Out:
# {'host': 'fdf2efd7045d', 'version': '4.4.3', 'process': 'mongod', 'pid': 1, 'uptime': 22415.0, 'uptimeMillis': 22414741, 'uptimeEstimate': 22414, 'localTime': datetime.datetime(2021, 2, 18, 16, 27, 33, 19000), 'asserts': {'regular': 0, 'warning': 0, 'msg': 0, 'user': 15, 'rollovers': 0}, 'connections': {'current': 4, 'available': 838856, 'totalCreated': 25, 'active': 1, 'exhaustIsMaster': 0, 'exhaustHello': 0, 'awaitingTopologyChanges': 0}, 'electionMetrics': {'stepUpCmd': {'called': 0, 'successful': 0}, 'priorityTakeover': {'called': 0, 'successful': 0}, 'catchUpTakeover': {'called': 0, 'successful': 0}, 'electionTimeout': {'called': 0, 'successful': 0}, 'freezeTimeout': {'called': 0, 'successful': 0}, 'numStepDownsCausedByHigherTerm': 0, 'numCatchUps': 0, 'numCatchUpsSucceeded': 0, 'numCatchUpsAlreadyCaughtUp': 0, 'numCatchUpsSkipped': 0, 'numCatchUpsTimedOut': 0, 'numCatchUpsFailedWithError': 0, 'numCatchUpsFailedWithNewTerm': 0, 'numCatchUpsFailedWithReplSetAbortPrimaryCatchUpCmd': 0, 'averageCatchUpOps': 0.0}, 'extra_info': {'note': 'fields vary by platform', 'user_time_us': 177952249, 'system_time_us': 111750069, 'maximum_resident_set_kb': 251348, 'input_blocks': 4648, 'output_blocks': 0, 'page_reclaims': 28426, 'page_faults': 24, 'voluntary_context_switches': 1850456, 'involuntary_context_switches': 4986}, 'flowControl': {'enabled': True, 'targetRateLimit': 1000000000, 'timeAcquiringMicros': 260511, 'locksPerKiloOp': 0.0, 'sustainerRate': 0, 'isLagged': False, 'isLaggedCount': 0, 'isLaggedTimeMicros': 0}, 'freeMonitoring': {'state': 'enabled', 'retryIntervalSecs': 60, 'lastRunTime': '2021-02-18T16:27:14.251+00:00', 'registerErrors': 0, 'metricsErrors': 0}, 'globalLock': {'totalTime': 22414732000, 'currentQueue': {'total': 0, 'readers': 0, 'writers': 0}, 'activeClients': {'total': 0, 'readers': 0, 'writers': 0}}, 'locks': {'ParallelBatchWriterMode': {'acquireCount': {'r': 546868}}, 'ReplicationStateTransition': {'acquireCount': {'w': 641250}}, 'Global': {'acquireCount': {'r': 94767, 'w': 546479, 'W': 4}}, 'Database': {'acquireCount': {'r': 9065, 'w': 546467, 'W': 12}}, 'Collection': {'acquireCount': {'r': 9144, 'w': 546461, 'W': 12}}, 'Mutex': {'acquireCount': {'r': 547942}}}, 'logicalSessionRecordCache': {'activeSessionsCount': 0, 'sessionsCollectionJobCount': 73, 'lastSessionsCollectionJobDurationMillis': 0, 'lastSessionsCollectionJobTimestamp': datetime.datetime(2021, 2, 18, 16, 25, 54, 174000), 'lastSessionsCollectionJobEntriesRefreshed': 0, 'lastSessionsCollectionJobEntriesEnded': 0, 'lastSessionsCollectionJobCursorsClosed': 0, 'transactionReaperJobCount': 73, 'lastTransactionReaperJobDurationMillis': 0, 'lastTransactionReaperJobTimestamp': datetime.datetime(2021, 2, 18, 16, 25, 54, 140000), 'lastTransactionReaperJobEntriesCleanedUp': 0, 'sessionCatalogSize': 0}, 'network': {'bytesIn': 227826909, 'bytesOut': 64200526, 'physicalBytesIn': 227826909, 'physicalBytesOut': 64200526, 'numSlowDNSOperations': 0, 'numSlowSSLOperations': 0, 'numRequests': 546403, 'tcpFastOpen': {'kernelSetting': 1, 'serverSupported': True, 'clientSupported': True, 'accepted': 0}, 'compression': {'snappy': {'compressor': {'bytesIn': 0, 'bytesOut': 0}, 'decompressor': {'bytesIn': 0, 'bytesOut': 0}}, 'zstd': {'compressor': {'bytesIn': 0, 'bytesOut': 0}, 'decompressor': {'bytesIn': 0, 'bytesOut': 0}}, 'zlib': {'compressor': {'bytesIn': 0, 'bytesOut': 0}, 'decompressor': {'bytesIn': 0, 'bytesOut': 0}}}, 'serviceExecutorTaskStats': {'executor': 'passthrough', 'threadsRunning': 4}}, 'opLatencies': {'reads': {'latency': 8047279, 'ops': 131}, 'writes': {'latency': 33504311, 'ops': 543649}, 'commands': {'latency': 500509, 'ops': 2622}, 'transactions': {'latency': 0, 'ops': 0}}, 'opReadConcernCounters': {'available': 0, 'linearizable': 0, 'local': 0, 'majority': 0, 'snapshot': 0, 'none': 118}, 'opcounters': {'insert': 562537, 'query': 118, 'update': 2376, 'delete': 6, 'getmore': 34, 'command': 2816}, 'opcountersRepl': {'insert': 0, 'query': 0, 'update':  ...

# %%
df_ks = pd.read_csv("./data/ks-projects-201801-sample.csv")
df_ks.head()
# Out:
# /root/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (6,8,10,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            ID                                               name  \
# 0   872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1  1326492673                                    Ohceola jewelry
# 2  1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3   156812982  SketchPlanner: Create and Plan- all in one bea...
# 4  1835968190    Proven sales with custom motorcycle accessories
#
#          category main_category currency    deadline   goal  \
# 0            Rock         Music      USD  2011-09-16   2000
# 1         Fashion       Fashion      USD  2012-08-22  18000
# 2  Tabletop Games         Games      USD  2016-07-19   2000
# 3       Art Books    Publishing      USD  2017-09-27  13000
# 4       Sculpture           Art      CAD  2016-02-24   5000
#
#               launched pledged       state backers country usd pledged  \
# 0  2011-08-17 06:31:31    1145    canceled      24      US        1145
# 1  2012-07-23 20:46:48    1851      failed      28      US        1851
# 2  2016-07-01 21:55:54    7534  successful     254      US        3796
# 3  2017-08-28 15:47:02   16298  successful     367      US        2670
# 4  2016-01-25 17:37:10       1      failed       1      CA    0.708148
#
#    usd_pledged_real
# 0       1145.000000
# 1       1851.000000
# 2       7534.000000
# 3      16298.000000
# 4          0.738225

# %% [markdown]
# Ce warning intervient lorsque pandas n'arrive pas à inférer le type de données. Il est sympa il précise les colones 6,8,10,12.

# %%
df_ks.columns[[6,8,10,12]]
# Out:
# Index(['goal', 'pledged', 'backers', 'usd pledged'], dtype='object')

# %% [markdown]
# ## Question 0

# %% [markdown]
# ### Nettoyer les données

# %%
df_ks['launched'] = pd.to_datetime(df_ks['launched'], errors='coerce')
df_ks = df_ks.dropna(subset=['launched'])
df_ks.rename(columns={'ID':'_id'}, inplace=True)
l_d =df_ks.to_dict(orient='records')

# %% [markdown]
# ### Importer les données

# %%
collection.drop()
for entry in l_d: 
    # print (type(entry),entry,  "\n")
    collection.insert_one(entry)

# %% [markdown]
# ## Question 1

# %%
# Sans mongo :
# sortedList = sorted(l_d, key=lambda entry: int(entry['backers']), reverse=True)[:5]
# sortedList

# Avec mongo :
sortedList = list(collection.find().sort("pledged", -1).limit(5))
sortedList
# Out:
# [{'_id': 218218259,
#   'name': 'True North ï¿½ Repurposed Sailcloth Products',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-06-14',
#   'goal': '7500.0',
#   'launched': datetime.datetime(2016, 5, 10, 15, 53, 56),
#   'pledged': '9996.0',
#   'state': 'successful',
#   'backers': '50',
#   'country': 'US',
#   'usd pledged': '9996.0',
#   'usd_pledged_real': 9996.0},
#  {'_id': 1712352341,
#   'name': 'Scott Davis - Solo Record',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2014-11-22',
#   'goal': '8000.0',
#   'launched': datetime.datetime(2014, 10, 23, 20, 6, 37),
#   'pledged': '9995.0',
#   'state': 'undefined',
#   'backers': '0',
#   'country': 'N,0"',
#   'usd pledged': nan,
#   'usd_pledged_real': 9995.0},
#  {'_id': 1742823215,
#   'name': 'Polco: A Digital Platform for Better Civic Communication',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-08-11',
#   'goal': '35000.0',
#   'launched': datetime.datetime(2017, 6, 27, 21, 46, 4),
#   'pledged': '9994.0',
#   'state': 'failed',
#   'backers': '93',
#   'country': 'US',
#   'usd pledged': '876.0',
#   'usd_pledged_real': 9994.0},
#  {'_id': 1247285954,
#   'name': '2016 Gaming Calendar',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-07-25',
#   'goal': '3000.0',
#   'launched': datetime.datetime(2015, 6, 26, 14, 57, 14),
#   'pledged': '9994.0',
#   'state': 'successful',
#   'backers': '258',
#   'country': 'US',
#   'usd pledged': '9994.0',
#   'usd_pledged_real': 9994.0},
#  {'_id': 796104705,
#   'name': 'The Girl in The Mountain - Film',
#   'category': 'Science Fiction',
#   'main_category': 'Film & Video',
#   'currency': 'GBP',
#   'deadline': '2015-10-01',
#   'goal': '6500.0',
#   'launched': datetime.datetime(2015, 8, 31, 2, 11, 11),
#   'pledged': '999.0',
#   'state': 'failed',
#   'backers': '12',
#   'country': 'GB',
#   'usd pledged': '1537.65168912',
#   'usd_pledged_real': 1515.1974761875872}]

# %% [markdown]
# ## Question 2

# %%
numberOfSuccessfullProjects = collection.count({"goal": {"$lte": "parseInt($usd_pledged_real)" }})
numberOfSuccessfullProjects
# Out:
# 65535

# %% [markdown]
# ## Question 3

# %%
# Sans mongo :
# from collections import Counter
# Counter(entry['category'] for entry in l_d)

# Avec mongo :
countOfCategories = collection.aggregate([{
    '$group':{
        '_id':"$category", 
        "count": {"$sum" : 1 }
    }
}]);
list(countOfCategories)
# Out:
# [{'_id': 'Design', 'count': 1641},
#  {'_id': 'Photo', 'count': 58},
#  {'_id': 'Documentary', 'count': 6498},
#  {'_id': 'Taxidermy', 'count': 7},
#  {'_id': 'Ceramics', 'count': 128},
#  {'_id': 'Comic Books', 'count': 1032},
#  {'_id': 'Punk', 'count': 127},
#  {'_id': 'Glass', 'count': 51},
#  {'_id': 'Quilts', 'count': 32},
#  {'_id': 'DIY Electronics', 'count': 358},
#  {'_id': 'Graphic Design', 'count': 765},
#  {'_id': 'Robots', 'count': 237},
#  {'_id': 'Community Gardens', 'count': 115},
#  {'_id': 'Shorts', 'count': 4857},
#  {'_id': 'Public Art', 'count': 1248},
#  {'_id': 'Gaming Hardware', 'count': 178},
#  {'_id': 'Animation', 'count': 1017},
#  {'_id': 'Jazz', 'count': 733},
#  {'_id': 'Jewelry', 'count': 472},
#  {'_id': 'Web', 'count': 2017},
#  {'_id': 'Food Trucks', 'count': 687},
#  {'_id': 'Nature', 'count': 219},
#  {'_id': 'Literary Spaces', 'count': 10},
#  {'_id': 'Blues', 'count': 113},
#  {'_id': 'Bacon', 'count': 78},
#  {'_id': 'Thrillers', 'count': 302},
#  {'_id': 'R&B', 'count': 172},
#  {'_id': 'Candles', 'count': 168},
#  {'_id': 'Immersive', 'count': 131},
#  {'_id': 'Dance', 'count': 901},
#  {'_id': 'Workshops', 'count': 59},
#  {'_id': 'Romance', 'count': 74},
#  {'_id': 'Games', 'count': 1331},
#  {'_id': 'Food', 'count': 4612},
#  {'_id': 'Narrative Film', 'count': 2099},
#  {'_id': 'Printing', 'count': 83},
#  {'_id': '3D Printing', 'count': 271},
#  {'_id': 'Translations', 'count': 76},
#  {'_id': 'Television', 'count': 401},
#  {'_id': 'Country & Folk', 'count': 1790},
#  {'_id': 'Civic Design', 'count': 130},
#  {'_id': 'Woodworking', 'count': 433},
#  {'_id': 'Theater', 'count': 2786},
#  {'_id': 'Conceptual Art', 'count': 393},
#  {'_id': 'Family', 'count': 130},
#  {'_id': 'Weaving', 'count': 38},
#  {'_id': 'Graphic Novels', 'count': 702},
#  {'_id': 'Poetry', 'count': 532},
#  {'_id': 'Performances', 'count': 414},
#  {'_id': 'Drinks', 'count': 995},
#  {'_id': 'Mobile Games', 'count': 650},
#  {'_id': 'Photography', 'count': 2239},
#  {'_id': 'Audio', 'count': 164},
#  {'_id': 'Flight', 'count': 158},
#  {'_id': 'Fantasy', 'count': 132},
#  {'_id': 'Video Games', 'count': 4799},
#  {'_id': 'Performance Art', 'count': 855},
#  {'_id': 'Crochet', 'count': 61},
#  {'_id': 'Architecture', 'count': 300},
#  {'_id': 'Wearables', 'count': 508},
#  {'_id': "Farmer's Markets", 'count': 175},
#  {'_id': 'Footwear', 'count': 379},
#  {'_id': 'Periodicals', 'count': 517},
#  {'_id': 'Interactive Design', 'count': 146},
#  {'_id': 'Stationery', 'count': 90},
#  {'_id': 'Animals', 'count': 97},
#  {'_id': 'Comics', 'count': 1931},
#  {'_id': 'Mixed Media', 'count': 1118},
#  {'_id': 'Kids', 'count': 109},
#  {'_id': 'Calendars', 'count': 112},
#  {'_id': 'Sculpture', 'count': 737},
#  {'_id': 'Action', 'count': 282},
#  {'_id': 'Indie Rock', 'count': 2192},
#  {'_id': 'Video', 'count': 147},
#  {'_id': 'Letterpress', 'count': 24},
#  {'_id': 'DIY', 'count': 480},
#  {'_id': "Children's Books", 'count': 2686},
#  {'_id': 'Typography', 'count': 44},
#  {'_id': 'Live Games', 'count': 394},
#  {'_id': 'Technology', 'count': 2690},
#  {'_id': 'Tabletop Games', 'count': 5581},
#  {'_id': 'Latin', 'count': 63},
#  {'_id': 'Print', 'count': 288},
#  {'_id': 'Music Videos', 'count': 299},
#  {'_id': 'World Music', 'count': 850},
#  {'_id': 'Fabrication Tools', 'count': 96},
#  {'_id': 'Festivals', 'count': 313},
#  {'_id': 'Cookbooks', 'count': 217},
#  {'_id': 'Makerspaces', 'count': 91},
#  {'_id': 'Childrenswear', 'count': 192},
#  {'_id': 'Electronic Music', 'count': 858},
#  {'_id': 'Gadgets', 'count': 1210},
#  {'_id': 'Fine Art', 'count': 291},
#  {'_id': 'Anthologies', 'count': 300},
#  {'_id': 'Painting', 'count': 1288},
#  {'_id': 'Fiction', 'count': 3703},
#  {'_id': 'Camera Equipment', 'count': 165},
#  {'_id': 'Rock', 'count': 2707},
#  {'_id': 'Digital Art', 'count': 524},
#  {'_id': 'Publishing', 'count': 2332},
#  {'_id': 'Film & Video', 'count': 4003},
#  {'_id': 'Journalism', 'count': 672},
#  {'_id': 'Software', 'count': 1194},
#  {'_id': 'Webseries', 'count': 2316},
#  {'_id': 'Metal', 'count': 274},
#  {'_id': 'Vegan', 'count': 229},
#  {'_id': 'Science Fiction', 'count': 274},
#  {'_id': 'Puzzles', 'count': 95},
#  {'_id': 'Spaces', 'count': 331},
#  {'_id': 'Movie Theaters', 'count': 90},
#  {'_id': 'Knitting', 'count': 78},
#  {'_id': 'Nonfiction', 'count': 3390},
#  {'_id': 'Academic', 'count': 367},
#  {'_id': 'Ready-to-wear', 'count': 332},
#  {'_id': 'Comedy', 'count': 923},
#  {'_id': 'Young Adult', 'count': 328},
#  {'_id': 'Crafts', 'count': 1834},
#  {'_id': 'Restaurants', 'count': 1089},
#  {'_id': 'Residencies', 'count': 32},
#  {'_id': 'Pottery', 'count': 40},
#  {'_id': 'Playing Cards', 'count': 963},
#  {'_id': 'Horror', 'count': 525},
#  {'_id': 'Art Books', 'count': 1065},
#  {'_id': 'Sound', 'count': 255},
#  {'_id': 'Installations', 'count': 178},
#  {'_id': 'Hip-Hop', 'count': 1555},
#  {'_id': 'Events', 'count': 322},
#  {'_id': 'Faith', 'count': 439},
#  {'_id': 'Experimental', 'count': 357},
#  {'_id': 'Webcomics', 'count': 259},
#  {'_id': 'Fashion', 'count': 3379},
#  {'_id': 'Accessories', 'count': 1204},
#  {'_id': 'Classical Music', 'count': 1064},
#  {'_id': 'Product Design', 'count': 8886},
#  {'_id': 'Hardware', 'count': 1431},
#  {'_id': 'Apps', 'count': 2535},
#  {'_id': 'Art', 'count': 3358},
#  {'_id': 'Music', 'count': 6229},
#  {'_id': 'Drama', 'count': 871},
#  {'_id': 'Pop', 'count': 1302},
#  {'_id': 'Literary Journals', 'count': 118},
#  {'_id': 'People', 'count': 440},
#  {'_id': 'Apparel', 'count': 2827},
#  {'_id': 'Musical', 'count': 367},
#  {'_id': 'Farms', 'count': 482},
#  {'_id': 'Illustration', 'count': 1263},
#  {'_id': 'Pet Fashion', 'count': 51},
#  {'_id': 'Video Art', 'count': 65},
#  {'_id': 'Embroidery', 'count': 49},
#  {'_id': 'Places', 'count': 283},
#  {'_id': 'Small Batch', 'count': 701},
#  {'_id': 'Zines', 'count': 144},
#  {'_id': 'Plays', 'count': 539},
#  {'_id': 'Radio & Podcasts', 'count': 349},
#  {'_id': 'Photobooks', 'count': 608},
#  {'_id': 'Textiles', 'count': 105},
#  {'_id': 'Space Exploration', 'count': 137},
#  {'_id': 'Couture', 'count': 108},
#  {'_id': 'Chiptune', 'count': 10}]

# %% [markdown]
# ## Question 4

# %%
from datetime import datetime

# Sans mongo :
# frenchProjects = sorted(l_d, key=lambda entry: 'FR' != entry['country'])
# frenchProjectsBefore2016 = sorted(frenchProjects, key=lambda entry: 2016 <= int(entry['launched'].year))
# frenchProjectsBefore2016


# Avec mongo :
frenchProjectsBefore2016 = collection.find({
    '$and': [
        {'country': {
            '$eq': "FR"
        }},
        {'launched': {
            '$lt': datetime(2016,1,1)
        }}
    ]
})
list(frenchProjectsBefore2016)
# Out:
# [{'_id': 545482362,
#   'name': 'Depeche Mode Bar Belgium',
#   'category': 'Pop',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2015-07-01',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 5, 27, 11, 29, 28),
#   'pledged': 305.0,
#   'state': 'failed',
#   'backers': 10,
#   'country': 'FR',
#   'usd pledged': 333.98121895,
#   'usd_pledged_real': 338.42637284599937},
#  {'_id': 400288569,
#   'name': 'Dracucat : A vampire kitten card game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-10-29',
#   'goal': 1900.0,
#   'launched': datetime.datetime(2015, 9, 29, 7, 4, 8),
#   'pledged': 2944.0,
#   'state': 'successful',
#   'backers': 129,
#   'country': 'FR',
#   'usd pledged': 3295.37237632,
#   'usd_pledged_real': 3243.3980764357875},
#  {'_id': 1990332786,
#   'name': 'Minotaur enjoy your life & your ice cream',
#   'category': 'Food Trucks',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2015-07-31',
#   'goal': 3800.0,
#   'launched': datetime.datetime(2015, 7, 11, 9, 19, 13),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 42552254,
#   'name': 'Catch Me',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-10-14',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 9, 19, 14, 48, 6),
#   'pledged': 226.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'FR',
#   'usd pledged': 257.54692190000003,
#   'usd_pledged_real': 256.73649293406646},
#  {'_id': 663285707,
#   'name': 'Co-park',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-11-12',
#   'goal': 2500.0,
#   'launched': datetime.datetime(2015, 10, 13, 11, 17, 28),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1859319535,
#   'name': 'Projet Coworking & Gaming',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-08-08',
#   'goal': 690000.0,
#   'launched': datetime.datetime(2015, 6, 9, 15, 33, 22),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1946351705,
#   'name': 'Banlieues - dix ans apr?s',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-11-08',
#   'goal': 40000.0,
#   'launched': datetime.datetime(2015, 9, 9, 11, 18, 16),
#   'pledged': 12579.0,
#   'state': 'failed',
#   'backers': 235,
#   'country': 'FR',
#   'usd pledged': 14042.99647443,
#   'usd_pledged_real': 13540.074487093929},
#  {'_id': 1452688704,
#   'name': 'Jungle House',
#   'category': 'Installations',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-11-25',
#   'goal': 12000.0,
#   'launched': datetime.datetime(2015, 11, 4, 15, 41, 26),
#   'pledged': 1350.0,
#   'state': 'failed',
#   'backers': 20,
#   'country': 'FR',
#   'usd pledged': 1486.859463,
#   'usd_pledged_real': 1428.2993715482764},
#  {'_id': 415130131,
#   'name': 'Holystream',
#   'category': 'Faith',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2016-01-16',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2015, 11, 27, 1, 58, 35),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1787211494,
#   'name': 'FURCY&FAIR',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-07-27',
#   'goal': 9000.0,
#   'launched': datetime.datetime(2015, 6, 26, 13, 48, 57),
#   'pledged': 9392.0,
#   'state': 'successful',
#   'backers': 71,
#   'country': 'FR',
#   'usd pledged': 10525.65516128,
#   'usd_pledged_real': 10300.165601044057},
#  {'_id': 537199454,
#   'name': 'www.worldoo.info Moteur de Recherche',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-08-11',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2015, 6, 12, 1, 10, 53),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 598062270,
#   'name': "Tonight I'll Dream About You",
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-07-21',
#   'goal': 5900.0,
#   'launched': datetime.datetime(2015, 6, 22, 19, 17, 34),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1046340865,
#   'name': 'Tikiwi, a "Kiwi style" Food Truck in France!',
#   'category': 'Food Trucks',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2015-12-14',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 10, 25, 19, 27, 21),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 630729432,
#   'name': 'Folky-Dolls... Cute LED table lamps for kids of the world!',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-07-20',
#   'goal': 130000.0,
#   'launched': datetime.datetime(2015, 6, 9, 6, 13, 23),
#   'pledged': 1266.0,
#   'state': 'failed',
#   'backers': 16,
#   'country': 'FR',
#   'usd pledged': 1405.16937972,
#   'usd_pledged_real': 1384.8779207140985},
#  {'_id': 912757617,
#   'name': 'Siesta, Nap.',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-12-31',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 12, 1, 18, 45, 21),
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 5.2934756,
#   'usd_pledged_real': 5.443480343592482},
#  {'_id': 1515614634,
#   'name': 'Chronologia Trigalight Dive Watch',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-08-07',
#   'goal': 35500.0,
#   'launched': datetime.datetime(2015, 7, 8, 8, 20, 48),
#   'pledged': 12445.0,
#   'state': 'failed',
#   'backers': 54,
#   'country': 'FR',
#   'usd pledged': 13734.97515005,
#   'usd_pledged_real': 13616.122714690533},
#  {'_id': 629586349,
#   'name': 'HUMANIMAGES',
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2015-07-16',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 6, 16, 23, 30, 42),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 137985493,
#   'name': "Grandpa, How Do You Make a  Kachina? - A children's book",
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2015-12-18',
#   'goal': 7000.0,
#   'launched': datetime.datetime(2015, 11, 13, 18, 5, 8),
#   'pledged': 7000.0,
#   'state': 'successful',
#   'backers': 84,
#   'country': 'FR',
#   'usd pledged': 7534.124220000002,
#   'usd_pledged_real': 7585.198027848513},
#  {'_id': 601724985,
#   'name': 'Shampoing MARLIVEIRA',
#   'category': 'DIY',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2015-10-25',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 9, 25, 20, 41, 48),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 338426049,
#   'name': 'Asterion- By director of FMA Brotherhood (Canceled)',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-07-28',
#   'goal': 135000.0,
#   'launched': datetime.datetime(2015, 6, 13, 11, 55, 3),
#   'pledged': 33785.0,
#   'state': 'canceled',
#   'backers': 155,
#   'country': 'FR',
#   'usd pledged': 38021.59406595,
#   'usd_pledged_real': 37051.8627375717},
#  {'_id': 1640048861,
#   'name': 'ARBITRELEC',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-11-30',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2015, 10, 31, 17, 1, 23),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 378181109,
#   'name': 'tiny & Tall: Gleipnir',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-10-08',
#   'goal': 8000.0,
#   'launched': datetime.datetime(2015, 9, 8, 9, 3, 3),
#   'pledged': 6817.0,
#   'state': 'failed',
#   'backers': 268,
#   'country': 'FR',
#   'usd pledged': 7603.20147418,
#   'usd_pledged_real': 7745.446695374547},
#  {'_id': 1730882800,
#   'name': '100 MECA',
#   'category': 'Photobooks',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2015-08-06',
#   'goal': 8000.0,
#   'launched': datetime.datetime(2015, 7, 12, 1, 47, 15),
#   'pledged': 320.0,
#   'state': 'failed',
#   'backers': 13,
#   'country': 'FR',
#   'usd pledged': 354.7722976,
#   'usd_pledged_real': 350.11323975098196},
#  {'_id': 1330309415,
#   'name': 'Today is a good day',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-07-11',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2015, 5, 27, 11, 6, 11),
#   'pledged': 285.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'FR',
#   'usd pledged': 312.08081115,
#   'usd_pledged_real': 310.3358160198615},
#  {'_id': 327985277,
#   'name': 'TOP SCHOOL',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-06-27',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 5, 28, 21, 40, 45),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1647853204,
#   'name': 'Omega Project',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-08-29',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2015, 7, 30, 23, 58, 32),
#   'pledged': 11.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 12.18702881,
#   'usd_pledged_real': 12.25176258311707},
#  {'_id': 35689425,
#   'name': 'Eyes of India - Exhibition - Exposition - Prints - Photos',
#   'category': 'Fine Art',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2015-10-02',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 9, 2, 0, 13, 32),
#   'pledged': 388.0,
#   'state': 'failed',
#   'backers': 8,
#   'country': 'FR',
#   'usd pledged': 436.11381972,
#   'usd_pledged_real': 433.00671830011385},
#  {'_id': 1933641835,
#   'name': 'Body scores',
#   'category': 'Photobooks',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2015-09-15',
#   'goal': 6000.0,
#   'launched': datetime.datetime(2015, 7, 31, 9, 46, 36),
#   'pledged': 50.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 54.866071999999996,
#   'usd_pledged_real': 57.09522341360922},
#  {'_id': 1523608703,
#   'name': 'Marcheese',
#   'category': 'Webcomics',
#   'main_category': 'Comics',
#   'currency': 'EUR',
#   'deadline': '2015-12-24',
#   'goal': 100.0,
#   'launched': datetime.datetime(2015, 11, 14, 15, 50, 26),
#   'pledged': 126.0,
#   'state': 'successful',
#   'backers': 5,
#   'country': 'FR',
#   'usd pledged': 135.97146738,
#   'usd_pledged_real': 137.9325444175634},
#  {'_id': 1896558868,
#   'name': 'Mots ?crits',
#   'category': 'Spaces',
#   'main_category': 'Theater',
#   'currency': 'EUR',
#   'deadline': '2015-07-16',
#   'goal': 2500.0,
#   'launched': datetime.datetime(2015, 6, 16, 11, 12, 17),
#   'pledged': 300.0,
#   'state': 'failed',
#   'backers': 12,
#   'country': 'FR',
#   'usd pledged': 336.223737,
#   'usd_pledged_real': 326.66928002090685},
#  {'_id': 1040232257,
#   'name': "Lucifer's rise",
#   'category': 'Fantasy',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-11-29',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2015, 9, 30, 17, 40, 25),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1673013190,
#   'name': 'LA BOX DEVINS',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2015-11-09',
#   'goal': 40000.0,
#   'launched': datetime.datetime(2015, 10, 10, 20, 26, 55),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1115987670,
#   'name': 'TTLamp: the New Flexible, Modular & Connected Lamp',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-12-23',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2015, 11, 24, 17, 45, 50),
#   'pledged': 398.0,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 422.36407148,
#   'usd_pledged_real': 435.69168792214475},
#  {'_id': 1546762014,
#   'name': 'Montaign Addict :  Accessoires de ski - Ski Accesories',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-02-07',
#   'goal': 8000.0,
#   'launched': datetime.datetime(2015, 12, 29, 17, 27, 25),
#   'pledged': 8410.0,
#   'state': 'successful',
#   'backers': 43,
#   'country': 'FR',
#   'usd pledged': 9230.813140600001,
#   'usd_pledged_real': 9482.25319081766},
#  {'_id': 391218466,
#   'name': 'WHOUHAOU! Immersive installation dedicated to dance',
#   'category': 'Dance',
#   'main_category': 'Dance',
#   'currency': 'EUR',
#   'deadline': '2015-06-26',
#   'goal': 27000.0,
#   'launched': datetime.datetime(2015, 5, 27, 19, 23, 5),
#   'pledged': 9200.0,
#   'state': 'failed',
#   'backers': 126,
#   'country': 'FR',
#   'usd pledged': 10074.187587999999,
#   'usd_pledged_real': 10305.813823232891},
#  {'_id': 1819520246,
#   'name': 'PINGA! Even Ha?ti needs Heroes...',
#   'category': 'Events',
#   'main_category': 'Comics',
#   'currency': 'EUR',
#   'deadline': '2015-08-13',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 7, 14, 12, 44, 43),
#   'pledged': 518.0,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'FR',
#   'usd pledged': 576.46636992,
#   'usd_pledged_real': 578.6545722647959},
#  {'_id': 1063655388,
#   'name': "Passions Automobiles  - Photos, tirages d'art - Art Pictures",
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2015-10-08',
#   'goal': 6500.0,
#   'launched': datetime.datetime(2015, 9, 18, 12, 12),
#   'pledged': 60.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 67.8518886,
#   'usd_pledged_real': 68.17174735550431},
#  {'_id': 26116111,
#   'name': "Faites revivre l'aviation fran?aise avec le HM 1000 Balerit",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-10-19',
#   'goal': 8000.0,
#   'launched': datetime.datetime(2015, 8, 20, 19, 44, 16),
#   'pledged': 175.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 193.30907575,
#   'usd_pledged_real': 193.97029483484815},
#  {'_id': 2123383062,
#   'name': 'Ulo',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-12-04',
#   'goal': 199000.0,
#   'launched': datetime.datetime(2015, 10, 5, 15, 48, 3),
#   'pledged': 1618869.12,
#   'state': 'successful',
#   'backers': 8330,
#   'country': 'FR',
#   'usd pledged': 1815079.1817613998,
#   'usd_pledged_real': 1764896.6705187191},
#  {'_id': 456970508,
#   'name': 'oracle des reflets - oracle/tarot deck',
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-10-06',
#   'goal': 3700.0,
#   'launched': datetime.datetime(2015, 9, 6, 21, 48, 52),
#   'pledged': 8591.0,
#   'state': 'successful',
#   'backers': 178,
#   'country': 'FR',
#   'usd pledged': 9577.76878916,
#   'usd_pledged_real': 9761.058025518958},
#  {'_id': 1302550415,
#   'name': "STARCAP 'The French Cap'",
#   'category': 'Ready-to-wear',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-07-29',
#   'goal': 7000.0,
#   'launched': datetime.datetime(2015, 5, 30, 9, 32, 56),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1917789498,
#   'name': "Let's Coffee App - Give or Take Free Coffee, meet people !",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-12-04',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 11, 5, 19, 44, 15),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 10.949640400000002,
#   'usd_pledged_real': 10.902034319604036},
#  {'_id': 1995297582,
#   'name': "Kat's Laser Crafts (Canceled)",
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-11-22',
#   'goal': 1300.0,
#   'launched': datetime.datetime(2015, 10, 14, 8, 54, 20),
#   'pledged': 30.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 34.072866,
#   'usd_pledged_real': 31.739986034406144},
#  {'_id': 1871137783,
#   'name': 'Pulssy Maxxi Wireless Speaker',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-06-26',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2015, 5, 27, 7, 41, 33),
#   'pledged': 151.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 165.34807889,
#   'usd_pledged_real': 169.14977035958327},
#  {'_id': 1668097693,
#   'name': 'Formation Cr?ation Couture Comme une Pro',
#   'category': 'Couture',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-06-26',
#   'goal': 8000.0,
#   'launched': datetime.datetime(2015, 5, 27, 3, 49, 36),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 10.985968699999999,
#   'usd_pledged_real': 11.201971546992269},
#  {'_id': 1750798706,
#   'name': 'French Riviera Candle',
#   'category': 'Candles',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2015-07-28',
#   'goal': 3925.0,
#   'launched': datetime.datetime(2015, 7, 2, 16, 7, 56),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1629922940,
#   'name': 'Made In France',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2015-06-22',
#   'goal': 600.0,
#   'launched': datetime.datetime(2015, 6, 2, 23, 51, 19),
#   'pledged': 600.0,
#   'state': 'successful',
#   'backers': 11,
#   'country': 'FR',
#   'usd pledged': 656.951088,
#   'usd_pledged_real': 672.1182928195362},
#  {'_id': 2003155960,
#   'name': 'Candle Lithophany personnalized',
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2015-09-22',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2015, 8, 23, 19, 59, 28),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1455581875,
#   'name': 'monkeywi - cache-webcam ultrafin prot?ge votre vie priv?e',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-11-13',
#   'goal': 1200.0,
#   'launched': datetime.datetime(2015, 10, 9, 0, 8, 49),
#   'pledged': 3893.0,
#   'state': 'successful',
#   'backers': 318,
#   'country': 'FR',
#   'usd pledged': 4388.11543835,
#   'usd_pledged_real': 4190.437234935739},
#  {'_id': 1162987071,
#   'name': 'PoDDI : Intelligent Showerhead - Water savings',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-10-10',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2015, 9, 10, 20, 6, 30),
#   'pledged': 15.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'FR',
#   'usd pledged': 16.771469699999994,
#   'usd_pledged_real': 17.040032716862818},
#  {'_id': 494291320,
#   'name': 'ClanSMG Serveur',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-06-27',
#   'goal': 500.0,
#   'launched': datetime.datetime(2015, 5, 28, 19, 59, 1),
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 5.4380277,
#   'usd_pledged_real': 5.547973325344252},
#  {'_id': 2048324945,
#   'name': 'R?ve de fer short film (Canceled)',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-07-07',
#   'goal': 4500.0,
#   'launched': datetime.datetime(2015, 6, 7, 12, 6, 38),
#   'pledged': 565.0,
#   'state': 'canceled',
#   'backers': 3,
#   'country': 'FR',
#   'usd pledged': 627.9145241,
#   'usd_pledged_real': 631.9557071752139},
#  {'_id': 1521723928,
#   'name': 'myGOURMET, the finest food around me',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2015-10-25',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 9, 25, 23, 26, 55),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1177360909,
#   'name': 'La V?tith?que, biblioth?que de v?tements ? Bordeaux.',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-08-23',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 6, 24, 13, 45, 54),
#   'pledged': 10236.0,
#   'state': 'successful',
#   'backers': 66,
#   'country': 'FR',
#   'usd pledged': 11550.25756632,
#   'usd_pledged_real': 11533.911005442438},
#  {'_id': 1183070862,
#   'name': 'REWIND - a Short Film',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-08-03',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2015, 7, 4, 16, 55, 12),
#   'pledged': 1098.0,
#   'state': 'successful',
#   'backers': 28,
#   'country': 'FR',
#   'usd pledged': 1217.87547858,
#   'usd_pledged_real': 1201.326053895557},
#  {'_id': 1179548226,
#   'name': "Construction d'un Bikepark",
#   'category': 'Architecture',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-08-11',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2015, 7, 12, 10, 36, 42),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1779919492,
#   'name': 'New light',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-12-12',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2015, 11, 12, 6, 35, 54),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 86530705,
#   'name': 'Nouveau jeu mobile/PC  ~~ New mobile/PC game',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-12-30',
#   'goal': 3200.0,
#   'launched': datetime.datetime(2015, 10, 31, 15, 9, 19),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 1.09808779,
#   'usd_pledged_real': 1.088696068718496},
#  {'_id': 1302039296,
#   'name': 'SephiGame',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-12-30',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2015, 10, 31, 18, 12, 56),
#   'pledged': 6.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 6.58852674,
#   'usd_pledged_real': 6.532176412310975},
#  {'_id': 671090174,
#   'name': 'Warn Da Nation Riddim',
#   'category': 'World Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2015-06-26',
#   'goal': 7000.0,
#   'launched': datetime.datetime(2015, 5, 27, 21, 35, 2),
#   'pledged': 32.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 35.04065248,
#   'usd_pledged_real': 35.846308950375274},
#  {'_id': 233068935,
#   'name': 'Give life to my creatures and adopt them !',
#   'category': 'Illustration',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-07-26',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2015, 5, 27, 7, 45, 57),
#   'pledged': 1538.0,
#   'state': 'successful',
#   'backers': 52,
#   'country': 'FR',
#   'usd pledged': 1684.14135982,
#   'usd_pledged_real': 1686.7179189103229},
#  {'_id': 375710096,
#   'name': 'Logiciel gratuit de facturation en ligne (Control ERP)',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-08-09',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 6, 10, 20, 34, 42),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1514912516,
#   'name': 'Tohu Bohu',
#   'category': 'Hip-Hop',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2015-12-10',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2015, 11, 19, 15, 24, 11),
#   'pledged': 2025.0,
#   'state': 'successful',
#   'backers': 106,
#   'country': 'FR',
#   'usd pledged': 2153.251998,
#   'usd_pledged_real': 2217.379878235732},
#  {'_id': 163312974,
#   'name': '1 Apps for 1 life',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-11-23',
#   'goal': 150000.0,
#   'launched': datetime.datetime(2015, 11, 3, 20, 54, 52),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 2044197681,
#   'name': 'Welcome to Another World!',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-11-27',
#   'goal': 35000.0,
#   'launched': datetime.datetime(2015, 10, 21, 12, 26, 50),
#   'pledged': 10331.0,
#   'state': 'failed',
#   'backers': 206,
#   'country': 'FR',
#   'usd pledged': 11710.93450151,
#   'usd_pledged_real': 10930.193190714996},
#  {'_id': 1524766221,
#   'name': 'ï¿½9 Universal Remote Control App for kid mum dad grandparents',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-06-26',
#   'goal': 19000.0,
#   'launched': datetime.datetime(2015, 5, 27, 9, 28, 38),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 204343701,
#   'name': 'ALTER WORLD',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-08-02',
#   'goal': 300.0,
#   'launched': datetime.datetime(2015, 7, 3, 9, 19, 40),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 45738099,
#   'name': 'FILM COMIQUE : Un Camping Car - Mon r?ve',
#   'category': 'Comedy',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-11-10',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2015, 9, 11, 2, 32, 30),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 550753770,
#   'name': 'MaTeHyS, a powerfull all-road individual electric vehicle.',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-12-05',
#   'goal': 100000.0,
#   'launched': datetime.datetime(2015, 11, 5, 11, 44, 31),
#   'pledged': 924.0,
#   'state': 'failed',
#   'backers': 14,
#   'country': 'FR',
#   'usd pledged': 1011.74677296,
#   'usd_pledged_real': 1011.7822259208972},
#  {'_id': 1114966662,
#   'name': 'Xculpter, the first hair and beard sculptor.',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-12-10',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 11, 12, 15, 37, 14),
#   'pledged': 1039.0,
#   'state': 'failed',
#   'backers': 16,
#   'country': 'FR',
#   'usd pledged': 1118.46467332,
#   'usd_pledged_real': 1137.7075029565065},
#  {'_id': 1871233881,
#   'name': 'Drops of Breath (Canceled)',
#   'category': 'Dance',
#   'main_category': 'Dance',
#   'currency': 'EUR',
#   'deadline': '2015-07-27',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 6, 27, 13, 45, 7),
#   'pledged': 766.0,
#   'state': 'canceled',
#   'backers': 24,
#   'country': 'FR',
#   'usd pledged': 856.73606274,
#   'usd_pledged_real': 840.068872487196},
#  {'_id': 998418451,
#   'name': 'Miami en vid?o',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-10-25',
#   'goal': 400.0,
#   'launched': datetime.datetime(2015, 9, 25, 4, 11, 49),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1073912995,
#   'name': 'MIKS - When language learning becomes a game',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-07-31',
#   'goal': 4000.0,
#   'launched': datetime.datetime(2015, 6, 16, 0, 26, 47),
#   'pledged': 11.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'FR',
#   'usd pledged': 12.39285806,
#   'usd_pledged_real': 12.063652215873573},
#  {'_id': 776737905,
#   'name': 'Charlie Fly - A Mobile Action Game - iOS & Android',
#   'category': 'Mobile Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-08-01',
#   'goal': 5600.0,
#   'launched': datetime.datetime(2015, 7, 3, 14, 26, 21),
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 2.21247504,
#   'usd_pledged_real': 2.188207748443637},
#  {'_id': 1483086435,
#   'name': 'Le Tribunal des Songes',
#   'category': 'Fantasy',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-12-30',
#   'goal': 350.0,
#   'launched': datetime.datetime(2015, 11, 30, 20, 49, 34),
#   'pledged': 353.0,
#   'state': 'successful',
#   'backers': 12,
#   'country': 'FR',
#   'usd pledged': 373.97395389999997,
#   'usd_pledged_real': 384.30971225762886},
#  {'_id': 1722631461,
#   'name': 'eResto : Restaurateurs, reprenez la maitrise !!!',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-07-14',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2015, 6, 23, 22, 6, 40),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1058418340,
#   'name': 'Le Chat et la Chouette',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-06-27',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2015, 5, 27, 8, 0, 50),
#   'pledged': 5175.0,
#   'state': 'successful',
#   'backers': 27,
#   'country': 'FR',
#   'usd pledged': 5666.73051825,
#   'usd_pledged_real': 5742.1523917313025},
#  {'_id': 1821949910,
#   'name': 'park my bike',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-09-04',
#   'goal': 9000.0,
#   'launched': datetime.datetime(2015, 8, 15, 0, 58, 28),
#   'pledged': 301.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'FR',
#   'usd pledged': 335.38351896,
#   'usd_pledged_real': 335.2527761380217},
#  {'_id': 166445711,
#   'name': 'Fontyou ï¿½ Simplify your typographic life',
#   'category': 'Typography',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-07-01',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2015, 5, 27, 8, 38, 59),
#   'pledged': 25525.0,
#   'state': 'successful',
#   'backers': 277,
#   'country': 'FR',
#   'usd pledged': 27950.39545475,
#   'usd_pledged_real': 28322.403825882408},
#  {'_id': 1121938624,
#   'name': 'Poil de carotte',
#   'category': 'Performances',
#   'main_category': 'Dance',
#   'currency': 'EUR',
#   'deadline': '2015-11-24',
#   'goal': 38000.0,
#   'launched': datetime.datetime(2015, 9, 25, 11, 39, 8),
#   'pledged': 258.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'FR',
#   'usd pledged': 288.49701899999997,
#   'usd_pledged_real': 272.96387989589283},
#  {'_id': 27628079,
#   'name': 'Fifties Cosmetics Parfumerie Ind?pendante',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-07-14',
#   'goal': 3000.0,
#   'launched': datetime.datetime(2015, 6, 9, 19, 22, 43),
#   'pledged': 3150.0,
#   'state': 'successful',
#   'backers': 36,
#   'country': 'FR',
#   'usd pledged': 3496.2745229999996,
#   'usd_pledged_real': 3430.0274402195228},
#  {'_id': 1674163196,
#   'name': '3d shingeki no kyojin map',
#   'category': 'Architecture',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-07-03',
#   'goal': 350.0,
#   'launched': datetime.datetime(2015, 6, 3, 20, 29, 5),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 562220091,
#   'name': 'Tokyo Reverse La Suite',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-07-02',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 5, 27, 8, 8, 51),
#   'pledged': 944.0,
#   'state': 'failed',
#   'backers': 21,
#   'country': 'FR',
#   'usd pledged': 1033.69924816,
#   'usd_pledged_real': 1047.457363824995},
#  {'_id': 1114030850,
#   'name': 'GOOD (OIYAA) START',
#   'category': 'Illustration',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-09-05',
#   'goal': 500.0,
#   'launched': datetime.datetime(2015, 8, 11, 19, 44, 17),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 1.09659584,
#   'usd_pledged_real': 1.1267986523488118},
#  {'_id': 282111032,
#   'name': 'Tunhell',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-07-14',
#   'goal': 3000.0,
#   'launched': datetime.datetime(2015, 6, 14, 21, 8, 36),
#   'pledged': 9504.0,
#   'state': 'successful',
#   'backers': 459,
#   'country': 'FR',
#   'usd pledged': 10707.42936384,
#   'usd_pledged_real': 10348.88279106233},
#  {'_id': 201728521,
#   'name': 'ALBA, a Romantic Fantasy Novel...',
#   'category': 'Fiction',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2016-02-11',
#   'goal': 500.0,
#   'launched': datetime.datetime(2015, 12, 13, 17, 52, 52),
#   'pledged': 72.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'FR',
#   'usd pledged': 79.14975552,
#   'usd_pledged_real': 81.17981328642944},
#  {'_id': 169131363,
#   'name': 'Cuisinez-vous le fran?ais?',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2015-11-13',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2015, 10, 14, 14, 17, 7),
#   'pledged': 50.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 56.788109999999996,
#   'usd_pledged_real': 53.820154571483926},
#  {'_id': 1031033139,
#   'name': 'Bouteilles or vin ros? / Bottles of rose wine (Suspended)',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2016-02-14',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 12, 16, 19, 13, 18),
#   'pledged': 0.0,
#   'state': 'suspended',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 476603680,
#   'name': 'Planeta Ginga Film Festival',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-10-09',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 9, 14, 1, 51, 58),
#   'pledged': 1201.0,
#   'state': 'failed',
#   'backers': 17,
#   'country': 'FR',
#   'usd pledged': 1361.65330228,
#   'usd_pledged_real': 1364.5711428993445},
#  {'_id': 1982275057,
#   'name': 'Casque de moto/scooter vintage en li?ge',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-01-02',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2015, 12, 4, 11, 23),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 355235395,
#   'name': 'Why Theatre',
#   'category': 'Spaces',
#   'main_category': 'Theater',
#   'currency': 'EUR',
#   'deadline': '2015-07-21',
#   'goal': 4200.0,
#   'launched': datetime.datetime(2015, 6, 8, 9, 9, 36),
#   'pledged': 4230.0,
#   'state': 'successful',
#   'backers': 41,
#   'country': 'FR',
#   'usd pledged': 4701.0237822,
#   'usd_pledged_real': 4627.198739826727},
#  {'_id': 678294728,
#   'name': 'Invite-only Dating App for unique quality dates (Canceled)',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-07-12',
#   'goal': 6500.0,
#   'launched': datetime.datetime(2015, 7, 2, 16, 53, 44),
#   'pledged': 1065.0,
#   'state': 'canceled',
#   'backers': 4,
#   'country': 'FR',
#   'usd pledged': 1185.84072555,
#   'usd_pledged_real': 1159.6759440742196},
#  {'_id': 1678794458,
#   'name': 'Polaroids from France',
#   'category': 'Places',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2015-09-20',
#   'goal': 500.0,
#   'launched': datetime.datetime(2015, 8, 31, 18, 25, 35),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 11.1819175,
#   'usd_pledged_real': 11.151006935926313},
#  {'_id': 2029690838,
#   'name': 'Ambasdr.  Learn to the world how to use social media.',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-11-11',
#   'goal': 3500.0,
#   'launched': datetime.datetime(2015, 10, 12, 7, 59, 29),
#   'pledged': 2007.0,
#   'state': 'failed',
#   'backers': 17,
#   'country': 'FR',
#   'usd pledged': 2279.7362475,
#   'usd_pledged_real': 2160.3410044993648},
#  {'_id': 208665246,
#   'name': "'' Album''Eyes to Eyes''of Kilimandjaro' '",
#   'category': 'World Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2016-01-31',
#   'goal': 8000.0,
#   'launched': datetime.datetime(2015, 12, 6, 22, 52, 38),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1159985516,
#   'name': '888bijouï¿½ le cadeau id?al : design, chance, amour et chic',
#   'category': 'Jewelry',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-07-14',
#   'goal': 2888.0,
#   'launched': datetime.datetime(2015, 5, 27, 7, 37, 47),
#   'pledged': 3336.0,
#   'state': 'successful',
#   'backers': 34,
#   'country': 'FR',
#   'usd pledged': 3652.98802104,
#   'usd_pledged_real': 3632.5623938324843},
#  {'_id': 2103464588,
#   'name': 'Wings of Justice',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-09-13',
#   'goal': 2200.0,
#   'launched': datetime.datetime(2015, 8, 10, 16, 30, 18),
#   'pledged': 556.0,
#   'state': 'failed',
#   'backers': 32,
#   'country': 'FR',
#   'usd pledged': 609.7246676,
#   'usd_pledged_real': 634.8988843593345},
#  {'_id': 1254718606,
#   'name': "Heart of Ice gamebook Collector's Edition (English / French)",
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-09-10',
#   'goal': 2000.0,
#   'launched': datetime.datetime(2015, 8, 26, 15, 18, 49),
#   'pledged': 4654.0,
#   'state': 'successful',
#   'backers': 125,
#   'country': 'FR',
#   'usd pledged': 5367.8672866000015,
#   'usd_pledged_real': 5244.120928031371},
#  {'_id': 1740138844,
#   'name': 'Abaros - Leather Belt',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2015-12-29',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 11, 24, 15, 46, 50),
#   'pledged': 15289.0,
#   'state': 'successful',
#   'backers': 175,
#   'country': 'FR',
#   'usd pledged': 16224.93539914,
#   'usd_pledged_real': 16645.074194637084},
#  {'_id': 824679072,
#   'name': 'Custom boxwood dice made in Jura',
#   'category': 'Woodworking',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2015-11-06',
#   'goal': 1500.0,
#   'launched': datetime.datetime(2015, 10, 7, 0, 41, 31),
#   'pledged': 365.0,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'FR',
#   'usd pledged': 410.27785215,
#   'usd_pledged_real': 396.53655197888037},
#  {'_id': 436973805,
#   'name': "My 2016, l'agenda de votre ann?e",
#   'category': 'Calendars',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2015-12-02',
#   'goal': 1200.0,
#   'launched': datetime.datetime(2015, 11, 10, 0, 2),
#   'pledged': 1767.0,
#   'state': 'successful',
#   'backers': 69,
#   'country': 'FR',
#   'usd pledged': 1897.96733649,
#   'usd_pledged_real': 1926.3894642740336},
#  {'_id': 1707789341,
#   'name': 'New World Vision',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-11-11',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 10, 2, 20, 31, 4),
#   'pledged': 31.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 34.61100028,
#   'usd_pledged_real': 33.368495834320036},
#  {'_id': 1807647480,
#   'name': 'DONUTS FACTORY',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2015-07-14',
#   'goal': 90000.0,
#   'launched': datetime.datetime(2015, 6, 9, 15, 39, 20),
#   'pledged': 192.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'FR',
#   'usd pledged': 213.10625664,
#   'usd_pledged_real': 209.0683392133804},
#  {'_id': 504259167,
#   'name': '"les recettes" : world food drawing and recipe on shirt',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-11-13',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 9, 24, 1, 19, 59),
#   'pledged': 130.0,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 145.6372138,
#   'usd_pledged_real': 139.9324018858582},
#  {'_id': 1711978703,
#   'name': 'TikiOne Steam Cleaner (Canceled)',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-10-02',
#   'goal': 2500.0,
#   'launched': datetime.datetime(2015, 8, 3, 22, 9, 21),
#   'pledged': 163.0,
#   'state': 'canceled',
#   'backers': 17,
#   'country': 'FR',
#   'usd pledged': 179.15552821,
#   'usd_pledged_real': 181.9074615539138},
#  {'_id': 414964217,
#   'name': 'Youfigure3D',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-07-19',
#   'goal': 44.0,
#   'launched': datetime.datetime(2015, 6, 24, 12, 5, 24),
#   'pledged': 446.0,
#   'state': 'successful',
#   'backers': 11,
#   'country': 'FR',
#   'usd pledged': 503.26444652,
#   'usd_pledged_real': 487.8795834427234},
#  {'_id': 2094487330,
#   'name': 'TPT (Tunisian Public Transport)',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-08-01',
#   'goal': 1546.0,
#   'launched': datetime.datetime(2015, 7, 2, 15, 11, 18),
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 5.56732735,
#   'usd_pledged_real': 5.470519371109092},
#  {'_id': 18939379,
#   'name': 'The Reversible Tie - La Cravate R?versible | Oh My Node',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-06-26',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 5, 27, 6, 25, 25),
#   'pledged': 10968.0,
#   'state': 'successful',
#   'backers': 100,
#   'country': 'FR',
#   'usd pledged': 12010.18363752,
#   'usd_pledged_real': 12286.322392741124},
#  {'_id': 1152345794,
#   'name': 'CREOLE SOUL',
#   'category': 'Ready-to-wear',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-01-14',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2015, 11, 25, 20, 53, 40),
#   'pledged': 525.0,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'FR',
#   'usd pledged': 558.25882875,
#   'usd_pledged_real': 572.9877216916782},
#  {'_id': 279280557,
#   'name': 'Zmei - Leather Goods & Accessories for Apple Watch & iPhone',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2016-01-15',
#   'goal': 6500.0,
#   'launched': datetime.datetime(2015, 12, 16, 16, 20, 21),
#   'pledged': 989.0,
#   'state': 'failed',
#   'backers': 8,
#   'country': 'FR',
#   'usd pledged': 1088.56086958,
#   'usd_pledged_real': 1079.399727148704},
#  {'_id': 499044406,
#   'name': 'Faire na?tre un violoncelle pour faire ?clore un talent',
#   'category': 'Classical Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2015-07-12',
#   'goal': 29000.0,
#   'launched': datetime.datetime(2015, 5, 28, 5, 55, 19),
#   'pledged': 35032.0,
#   'state': 'successful',
#   'backers': 193,
#   'country': 'FR',
#   'usd pledged': 38360.75430248,
#   'usd_pledged_real': 38146.26072564136},
#  {'_id': 635253293,
#   'name': 'Kling | Smartphone ring and grip holder (Canceled)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-07-31',
#   'goal': 7000.0,
#   'launched': datetime.datetime(2015, 6, 19, 15, 30, 42),
#   'pledged': 1411.0,
#   'state': 'canceled',
#   'backers': 59,
#   'country': 'FR',
#   'usd pledged': 1602.49129698,
#   'usd_pledged_real': 1547.4375705997827},
#  {'_id': 998248740,
#   'name': 'Wamaw Wallet : The minimalist leather card-holder handmade',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-10-19',
#   'goal': 1800.0,
#   'launched': datetime.datetime(2015, 9, 17, 19, 36, 49),
#   'pledged': 1806.0,
#   'state': 'successful',
#   'backers': 79,
#   'country': 'FR',
#   'usd pledged': 2038.24358136,
#   'usd_pledged_real': 2001.7734426956326},
#  {'_id': 1785964163,
#   'name': 'Tom and Jey - Made To Measure Bamboo Custom Dress Shirts',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-12-03',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 10, 31, 19, 4),
#   'pledged': 10649.05,
#   'state': 'successful',
#   'backers': 72,
#   'country': 'FR',
#   'usd pledged': 11693.5917800995,
#   'usd_pledged_real': 11609.630857117936},
#  {'_id': 339897138,
#   'name': 'XV Academy, rugby on a boardgame',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-11-16',
#   'goal': 200000.0,
#   'launched': datetime.datetime(2015, 10, 17, 16, 17, 48),
#   'pledged': 623.0,
#   'state': 'failed',
#   'backers': 10,
#   'country': 'FR',
#   'usd pledged': 708.72044523,
#   'usd_pledged_real': 665.8615050821372},
#  {'_id': 2100439267,
#   'name': "Fabled Lands: The Serpent King's Domain",
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-08-03',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2015, 7, 8, 18, 1, 50),
#   'pledged': 30589.1,
#   'state': 'successful',
#   'backers': 513,
#   'country': 'FR',
#   'usd pledged': 33759.785324419,
#   'usd_pledged_real': 33467.65281895863},
#  {'_id': 1269979500,
#   'name': 'La Tulipe 123 jouet pour adults en bois nobles (Suspended)',
#   'category': 'Woodworking',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2015-07-11',
#   'goal': 11000.0,
#   'launched': datetime.datetime(2015, 6, 12, 13, 40, 22),
#   'pledged': 0.0,
#   'state': 'suspended',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1158181063,
#   'name': 'Financement et aide ? la cr?ation',
#   'category': 'Plays',
#   'main_category': 'Theater',
#   'currency': 'EUR',
#   'deadline': '2015-07-26',
#   'goal': 5000.0,
#   'launched': datetime.datetime(2015, 5, 27, 7, 42, 16),
#   'pledged': 250.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'FR',
#   'usd pledged': 273.75509750000003,
#   'usd_pledged_real': 274.1739139971266},
#  {'_id': 2096475430,
#   'name': 'THE 7th CONTINENT - Explore. Survive. YOU are the hero!',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-10-27',
#   'goal': 50000.0,
#   'launched': datetime.datetime(2015, 9, 29, 21, 0, 7),
#   'pledged': 1224220.89,
#   'state': 'successful',
#   'backers': 12103,
#   'country': 'FR',
#   'usd pledged': 1370334.13838991,
#   'usd_pledged_real': 1348721.3586136235},
#  {'_id': 1112723391,
#   'name': 'The Mondrian, your custom 3D printer',
#   'category': '3D Printing',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-01-09',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2015, 12, 5, 6, 5, 30),
#   'pledged': 23210.0,
#   'state': 'failed',
#   'backers': 54,
#   'country': 'FR',
#   'usd pledged': 25367.7835664,
#   'usd_pledged_real': 25331.514324693042},
#  {'_id': 1697381402,
#   'name': 'Les 4 prisonniers et le donjon souterrain(English available)',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2015-06-26',
#   'goal': 10000.0,
#   'launched': datetime.datetime(2015, 5, 27, 8, 22, 57),
#   'pledged': 68.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 74.46138652,
#   'usd_pledged_real': 76.17340651954743},
#  {'_id': 1842530362,
#   'name': 'The most useful social web in the world "BIMP"',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-01-10',
#   'goal': 48860.0,
# ...
#  {'_id': 48403203,
#   'name': 'Pins Ensta/Ensieta/?cole militaire Lyc?e Naval',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2015-10-08',
#   'goal': '200.0',
#   'launched': datetime.datetime(2015, 9, 8, 22, 35, 1),
#   'pledged': '1.0',
#   'state': 'failed',
#   'backers': '1',
#   'country': 'FR',
#   'usd pledged': '1.11532954',
#   'usd_pledged_real': 1.1361957892584051},
#  {'_id': 1265862244,
#   'name': 'BYE - R?seau social pour rompre !',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-12-11',
#   'goal': '390000.0',
#   'launched': datetime.datetime(2015, 11, 11, 17, 46, 37),
#   'pledged': '0.0',
#   'state': 'failed',
#   'backers': '0',
#   'country': 'FR',
#   'usd pledged': '0.0',
#   'usd_pledged_real': 0.0},
#  {'_id': 64050173,
#   'name': "Cr?ation d'une boutique bijoux et mode",
#   'category': 'Jewelry',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-10-29',
#   'goal': '30000.0',
#   'launched': datetime.datetime(2015, 9, 25, 12, 35, 8),
#   'pledged': '0.0',
#   'state': 'failed',
#   'backers': '0',
#   'country': 'FR',
#   'usd pledged': '0.0',
#   'usd_pledged_real': 0.0},
#  {'_id': 1133857635,
#   'name': "Les Lettres de l'Alphabet, jeu ?ducatif pour enfants",
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2016-01-08',
#   'goal': '3000.0',
#   'launched': datetime.datetime(2015, 12, 9, 8, 46, 21),
#   'pledged': '5.0',
#   'state': 'failed',
#   'backers': '1',
#   'country': 'FR',
#   'usd pledged': '5.42664265',
#   'usd_pledged_real': 5.4304736459113965},
#  {'_id': 2118888011,
#   'name': 'LUNA - Luxury Sleep Mask with NAP & Lucid Dream Features',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-07-03',
#   'goal': '25000.0',
#   'launched': datetime.datetime(2015, 5, 29, 2, 9, 24),
#   'pledged': '13072.0',
#   'state': 'canceled',
#   'backers': '120',
#   'country': 'FR',
#   'usd pledged': '14217.17961888',
#   'usd_pledged_real': 14504.621461780012},
#  {'_id': 1556193939,
#   'name': 'The Album To Support French community for black friday',
#   'category': 'World Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2016-01-13',
#   'goal': 35000.0,
#   'launched': datetime.datetime(2015, 11, 14, 17, 2, 3),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 977207362,
#   'name': 'Zoby Z?',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-09-05',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 7, 22, 22, 33, 19),
#   'pledged': 292.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'FR',
#   'usd pledged': 316.24971232,
#   'usd_pledged_real': 329.02520648585306},
#  {'_id': 1325039752,
#   'name': 'No Gig Impossible : uchronian dream gigs, collector posters.',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2015-12-25',
#   'goal': 9710.0,
#   'launched': datetime.datetime(2015, 11, 25, 18, 36, 29),
#   'pledged': 125.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'FR',
#   'usd pledged': 132.91876875,
#   'usd_pledged_real': 136.087008589812},
#  {'_id': 197599880,
#   'name': 'THE DEVIL DOGS',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-07-27',
#   'goal': 30000.0,
#   'launched': datetime.datetime(2015, 5, 28, 21, 11, 25),
#   'pledged': 30320.0,
#   'state': 'successful',
#   'backers': 105,
#   'country': 'FR',
#   'usd pledged': 32976.1999728,
#   'usd_pledged_real': 33251.81228957152},
#  {'_id': 2018078323,
#   'name': 'Kitchen Trotter : un voyage ? cuisiner - a trip to cook !',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'EUR',
#   'deadline': '2015-07-10',
#   'goal': 20000.0,
#   'launched': datetime.datetime(2015, 5, 27, 8, 12, 55),
#   'pledged': 20689.0,
#   'state': 'successful',
#   'backers': 359,
#   'country': 'FR',
#   'usd pledged': 22654.87684871,
#   'usd_pledged_real': 23140.763939377},
#  {'_id': 813865095,
#   'name': 'Komodor: V?tements graphiques de qualit? design?s en France',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-10-14',
#   'goal': 5500.0,
#   'launched': datetime.datetime(2015, 9, 14, 10, 0, 52),
#   'pledged': 1642.0,
#   'state': 'failed',
#   'backers': 31,
#   'country': 'FR',
#   'usd pledged': 1861.64423176,
#   'usd_pledged_real': 1865.3155814059164},
#  {'_id': 1593053116,
#   'name': 'The Prophecy of Amat (Canceled)',
#   'category': 'Fiction',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2015-12-06',
#   'goal': 6000.0,
#   'launched': datetime.datetime(2015, 11, 6, 15, 5, 17),
#   'pledged': 680.0,
#   'state': 'canceled',
#   'backers': 20,
#   'country': 'FR',
#   'usd pledged': 739.2469447999997,
#   'usd_pledged_real': 744.6016381236038},
#  {'_id': 1878604968,
#   'name': 'VARIATIONS',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-10-24',
#   'goal': 8000.0,
#   'launched': datetime.datetime(2015, 9, 21, 21, 59, 22),
#   'pledged': 12.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 13.56407328,
#   'usd_pledged_real': 13.220372594167616},
#  {'_id': 530682273,
#   'name': 'Rendons ? Marie-Antoinette...son ?pinette',
#   'category': 'Classical Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2015-10-14',
#   'goal': 35000.0,
#   'launched': datetime.datetime(2015, 8, 30, 16, 34, 53),
#   'pledged': 51.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 57.02777925,
#   'usd_pledged_real': 57.93611123733358},
#  {'_id': 726258998,
#   'name': 'Customisation Sneakers',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2015-11-09',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2015, 9, 23, 9, 41, 17),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1388326878,
#   'name': 'REFLEXION CONTRE NATURE',
#   'category': 'Nature',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2015-07-05',
#   'goal': 2500.0,
#   'launched': datetime.datetime(2015, 6, 14, 21, 6, 23),
#   'pledged': 2519.0,
#   'state': 'successful',
#   'backers': 22,
#   'country': 'FR',
#   'usd pledged': 2837.96449574,
#   'usd_pledged_real': 2817.5157988926794},
#  {'_id': 679439475,
#   'name': 'SOLAR KIT BOX & BATTERY UNIT: Save On Your Electricity Bill!',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-07-23',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2015, 6, 23, 23, 40, 42),
#   'pledged': 8683.0,
#   'state': 'failed',
#   'backers': 54,
#   'country': 'FR',
#   'usd pledged': 9878.93381557,
#   'usd_pledged_real': 9498.337271374814},
#  {'_id': 148873286,
#   'name': 'Ride Europe and USA to Dance the World',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-08-26',
#   'goal': 25000.0,
#   'launched': datetime.datetime(2015, 8, 11, 19, 29, 52),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1674716636,
#   'name': 'Aller voir mes 2 seuls amis en suisse',
#   'category': 'Nature',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2016-01-18',
#   'goal': 1100.0,
#   'launched': datetime.datetime(2015, 11, 19, 4, 38, 55),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 781355584,
#   'name': 'Reportage sur Mr Mickey Mouse',
#   'category': 'Video',
#   'main_category': 'Journalism',
#   'currency': 'EUR',
#   'deadline': '2015-06-30',
#   'goal': 400.0,
#   'launched': datetime.datetime(2015, 6, 21, 18, 33, 41),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 916472687,
#   'name': 'Imprimerie 3D - Fablab en zone rurale',
#   'category': '3D Printing',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-07-31',
#   'goal': 3000.0,
#   'launched': datetime.datetime(2015, 6, 18, 16, 21, 51),
#   'pledged': 100.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 112.539867,
#   'usd_pledged_real': 109.66956559885062},
#  {'_id': 263025244,
#   'name': 'UnitMaker',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-09-18',
#   'goal': 4000.0,
#   'launched': datetime.datetime(2015, 8, 19, 8, 38, 19),
#   'pledged': 85.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'FR',
#   'usd pledged': 94.16383640000001,
#   'usd_pledged_real': 97.06187980313568},
#  {'_id': 2101577594,
#   'name': 'Cold Blooded',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-07-22',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 6, 22, 11, 49, 13),
#   'pledged': 517.0,
#   'state': 'failed',
#   'backers': 34,
#   'country': 'FR',
#   'usd pledged': 586.9197521000001,
#   'usd_pledged_real': 565.5465126454887},
#  {'_id': 2146589298,
#   'name': 'Tutoriel complet Aquarium Juwel 450 vision ultra plant?',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-12-22',
#   'goal': 4000.0,
#   'launched': datetime.datetime(2015, 10, 23, 0, 28, 25),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 831858023,
#   'name': 'Deleez Cookies (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-12-16',
#   'goal': 1000.0,
#   'launched': datetime.datetime(2015, 11, 16, 21, 35, 20),
#   'pledged': 86.0,
#   'state': 'canceled',
#   'backers': 6,
#   'country': 'FR',
#   'usd pledged': 92.6326855,
#   'usd_pledged_real': 93.18957577071028},
#  {'_id': 1887864427,
#   'name': 'The First International B2B Networking Platform.',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-08-05',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2015, 7, 6, 18, 31, 59),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1316370878,
#   'name': 'MUSE DELTA',
#   'category': '3D Printing',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-11-21',
#   'goal': 90000.0,
#   'launched': datetime.datetime(2015, 10, 22, 18, 20, 58),
#   'pledged': 1415.0,
#   'state': 'failed',
#   'backers': 8,
#   'country': 'FR',
#   'usd pledged': 1607.249541,
#   'usd_pledged_real': 1497.0693412894898},
#  {'_id': 1089062782,
#   'name': 'APPARENCES: a photography project about people and light',
#   'category': 'People',
#   'main_category': 'Photography',
#   'currency': 'EUR',
#   'deadline': '2015-09-21',
#   'goal': 2000.0,
#   'launched': datetime.datetime(2015, 8, 7, 23, 40, 19),
#   'pledged': 2108.0,
#   'state': 'successful',
#   'backers': 25,
#   'country': 'FR',
#   'usd pledged': 2298.77286168,
#   'usd_pledged_real': 2350.632262093267},
#  {'_id': 1327570430,
#   'name': 'r?n',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2015-07-18',
#   'goal': 60000.0,
#   'launched': datetime.datetime(2015, 6, 18, 17, 55, 55),
#   'pledged': 86.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 96.78428562,
#   'usd_pledged_real': 94.0754353723637},
#  {'_id': 1033114039,
#   'name': 'C&G (Canceled)',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-07-13',
#   'goal': 29000.0,
#   'launched': datetime.datetime(2015, 6, 5, 12, 45, 16),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'FR',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 109832866,
#   'name': 'New PC Game Hit Tank PRO Steam Greenlight Need help !!!',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-11-14',
#   'goal': 1500.0,
#   'launched': datetime.datetime(2015, 10, 15, 17, 41, 34),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'FR',
#   'usd pledged': 1.13906244,
#   'usd_pledged_real': 1.0687985635347306},
#  {'_id': 688601772,
#   'name': 'Stephen Hawking Hologram Project',
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'currency': 'EUR',
#   'deadline': '2015-09-15',
#   'goal': 15000.0,
#   'launched': datetime.datetime(2015, 7, 21, 9, 16, 56),
#   'pledged': 1108.0,
#   'state': 'failed',
#   'backers': 10,
#   'country': 'FR',
#   'usd pledged': 1199.44315136,
#   'usd_pledged_real': 1265.2301508455805},
#  {'_id': 205663955,
#   'name': "Cr?ation d'un atelier de costume ind?pendant",
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'EUR',
#   'deadline': '2015-08-26',
#   'goal': 1500.0,
#   'launched': datetime.datetime(2015, 7, 27, 18, 20, 54),
#   'pledged': 1841.0,
#   'state': 'successful',
#   'backers': 26,
#   'country': 'FR',
#   'usd pledged': 2021.37985448,
#   'usd_pledged_real': 2074.4363189741625},
#  {'_id': 1170494966,
#   'name': 'a Family of Grave Diggers (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-08-09',
#   'goal': 6000.0,
#   'launched': datetime.datetime(2015, 7, 11, 18, 7, 55),
#   'pledged': 174.0,
#   'state': 'canceled',
#   'backers': 20,
#   'country': 'FR',
#   'usd pledged': 192.90743682,
#   'usd_pledged_real': 194.37431578006652},
#  {'_id': 587734625,
#   'name': 'The Bakounines (2016) - 2nd EP !',
#   'category': 'Punk',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2015-12-13',
#   'goal': 700.0,
#   'launched': datetime.datetime(2015, 10, 19, 14, 12, 14),
#   'pledged': 770.0,
#   'state': 'successful',
#   'backers': 14,
#   'country': 'FR',
#   'usd pledged': 873.8669555,
#   'usd_pledged_real': 834.3717830633365},
#  {'_id': 83153281,
#   'name': 'Wram - Handcrafted full grain leather wallet and card-holder',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-11-07',
#   'goal': 1200.0,
#   'launched': datetime.datetime(2015, 10, 8, 15, 39, 54),
#   'pledged': 3685.0,
#   'state': 'successful',
#   'backers': 104,
#   'country': 'FR',
#   'usd pledged': 4153.66180075,
#   'usd_pledged_real': 3966.5453919183656},
#  {'_id': 12134418,
#   'name': 'New AMIGA 1200 Cases (Made From New Molds)',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2015-11-01',
#   'goal': 125000.0,
#   'launched': datetime.datetime(2015, 9, 2, 12, 0, 19),
#   'pledged': 156310.02,
#   'state': 'successful',
#   'backers': 840,
#   'country': 'FR',
#   'usd pledged': 176145.799052405,
#   'usd_pledged_real': 169815.44211109538},
#  {'_id': 508223995,
#   'name': 'Sijak Taekwondo Card Game / Jeu de Cartes (Canceled)',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-12-14',
#   'goal': 6500.0,
#   'launched': datetime.datetime(2015, 11, 21, 18, 20, 23),
#   'pledged': 1340.0,
#   'state': 'canceled',
#   'backers': 28,
#   'country': 'FR',
#   'usd pledged': 1435.6117470000006,
#   'usd_pledged_real': 1452.0236224738587},
#  {'_id': 299205964,
#   'name': '10 ans de Mariage ! - Spectacle com?die au Qu?bec (Canceled)',
#   'category': 'Plays',
#   'main_category': 'Theater',
#   'currency': 'EUR',
#   'deadline': '2015-10-05',
#   'goal': 2000.0,
#   'launched': datetime.datetime(2015, 9, 9, 19, 37, 12),
#   'pledged': 130.0,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'FR',
#   'usd pledged': 145.1299421,
#   'usd_pledged_real': 147.70545260359262},
#  {'_id': 1115857606,
#   'name': 'Saint-Matthieu',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'EUR',
#   'deadline': '2015-08-19',
#   'goal': 99.0,
#   'launched': datetime.datetime(2015, 7, 20, 20, 49, 42),
#   'pledged': 100.0,
#   'state': 'successful',
#   'backers': 6,
#   'country': 'FR',
#   'usd pledged': 108.29918300000001,
#   'usd_pledged_real': 112.80952112358284}]

# %% [markdown]
# ## Question 5

# %%
from datetime import datetime

# Sans mongo :
# frenchProjects = sorted(l_d, key=lambda entry: 'FR' != entry['country'])
# frenchProjectsBefore2016 = sorted(frenchProjects, key=lambda entry: 2016 <= int(entry['launched'].year))
# frenchProjectsBefore2016


# Avec mongo :
americanProjectsWithLotOfDollars = collection.find({
    '$and': [
        {'country': {
            '$eq': "US"
        }},
        {'goal': {
            '$gt': 200000.0
        }}
    ]
})
list(americanProjectsWithLotOfDollars)
# Out:
# [{'_id': 866634482,
#   'name': 'A CALL TO ADVENTURE',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-09-14',
#   'goal': 287000.0,
#   'launched': datetime.datetime(2012, 8, 13, 23, 14, 2),
#   'pledged': 1465.0,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'US',
#   'usd pledged': 1465.0,
#   'usd_pledged_real': 1465.0},
#  {'_id': 993194166,
#   'name': 'Storybricks, the storytelling online RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-06-01',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2012, 5, 1, 20, 49, 58),
#   'pledged': 23680.54,
#   'state': 'failed',
#   'backers': 409,
#   'country': 'US',
#   'usd pledged': 23680.54,
#   'usd_pledged_real': 23680.54},
#  {'_id': 1147175344,
#   'name': 'Shine On New World',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2013-11-04',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2013, 9, 30, 18, 18, 40),
#   'pledged': 12314.0,
#   'state': 'failed',
#   'backers': 50,
#   'country': 'US',
#   'usd pledged': 12314.0,
#   'usd_pledged_real': 12314.0},
#  {'_id': 2012810303,
#   'name': 'Nightclub',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2017-09-10',
#   'goal': 3000000.0,
#   'launched': datetime.datetime(2017, 8, 11, 18, 8, 7),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 593221398,
#   'name': 'Nastaran (Wild Rose)',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-06-30',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2015, 5, 8, 21, 3, 20),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 621936552,
#   'name': 'Hubo - Extension Box for iPhone',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-11-26',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2016, 10, 27, 17, 43, 14),
#   'pledged': 1996.0,
#   'state': 'failed',
#   'backers': 10,
#   'country': 'US',
#   'usd pledged': 438.0,
#   'usd_pledged_real': 1996.0},
#  {'_id': 1323150226,
#   'name': 'Baja ATV Park (Suspended)',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-05-31',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2016, 4, 1, 22, 4, 54),
#   'pledged': 11.0,
#   'state': 'suspended',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 11.0,
#   'usd_pledged_real': 11.0},
#  {'_id': 61436443,
#   'name': 'Chihuly Installation for Orlando (Pulse Nightclub)',
#   'category': 'Installations',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2016-08-12',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2016, 7, 13, 17, 31, 26),
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 4.0,
#   'usd_pledged_real': 5.0},
#  {'_id': 821637012,
#   'name': 'Kurt Vonnegut: Unstuck in Time',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-03-10',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2015, 2, 10, 14, 5, 34),
#   'pledged': 300319.0,
#   'state': 'successful',
#   'backers': 3755,
#   'country': 'US',
#   'usd pledged': 300319.0,
#   'usd_pledged_real': 300319.0},
#  {'_id': 924370408,
#   'name': 'The LAKE HOPPER is a VTOL Flying Water Craft Made in America',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-12-15',
#   'goal': 3000000.0,
#   'launched': datetime.datetime(2016, 11, 15, 21, 6, 46),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 966762561,
#   'name': '"Hill" (11 For 11) (From the writer of Rudy & Hoosiers)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-12-12',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2012, 11, 12, 23, 27, 51),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 673847752,
#   'name': 'Saints of The Classroom',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-11-18',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2016, 10, 19, 2, 5, 16),
#   'pledged': 3085.0,
#   'state': 'failed',
#   'backers': 24,
#   'country': 'US',
#   'usd pledged': 1915.0,
#   'usd_pledged_real': 3085.0},
#  {'_id': 1751772364,
#   'name': 'Hemingwrite - A Distraction Free Digital Typewriter',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-01-23',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2014, 12, 10, 18, 58, 8),
#   'pledged': 342471.0,
#   'state': 'successful',
#   'backers': 1096,
#   'country': 'US',
#   'usd pledged': 342471.0,
#   'usd_pledged_real': 342471.0},
#  {'_id': 1529289950,
#   'name': 'Breakfast 24/7',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-07-02',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2016, 5, 18, 0, 36, 35),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 314981144,
#   'name': 'FJE REVOLT',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-02-10',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2015, 1, 14, 3, 1, 52),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 208383561,
#   'name': 'Austin City Limits 40 Year History Documentary Film',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-09-30',
#   'goal': 400000.0,
#   'launched': datetime.datetime(2014, 8, 29, 20, 46, 59),
#   'pledged': 9.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 9.0,
#   'usd_pledged_real': 9.0},
#  {'_id': 912070501,
#   'name': 'Ozark Mountain Ranch',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-04-06',
#   'goal': 466000.0,
#   'launched': datetime.datetime(2015, 2, 10, 19, 11, 52),
#   'pledged': 1076.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 1076.0,
#   'usd_pledged_real': 1076.0},
#  {'_id': 2116069761,
#   'name': 'STEM Lesson Plan - BotBrainï¿½ Educational Products',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-10-07',
#   'goal': 279646.0,
#   'launched': datetime.datetime(2014, 9, 4, 18, 26, 25),
#   'pledged': 85.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'US',
#   'usd pledged': 85.0,
#   'usd_pledged_real': 85.0},
#  {'_id': 410799527,
#   'name': 'Guitar Godz VR: A 3D Rock Music Game',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-04-04',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2017, 3, 28, 19, 0, 52),
#   'pledged': 22612.0,
#   'state': 'failed',
#   'backers': 36,
#   'country': 'US',
#   'usd pledged': 12311.0,
#   'usd_pledged_real': 22612.0},
#  {'_id': 848767036,
#   'name': "The world's first crowd funded millionaire documentary",
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-05-24',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2015, 4, 24, 2, 58, 26),
#   'pledged': 171.0,
#   'state': 'failed',
#   'backers': 17,
#   'country': 'US',
#   'usd pledged': 171.0,
#   'usd_pledged_real': 171.0},
#  {'_id': 1520402606,
#   'name': 'Creating an online game, "Perdition Online".',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-11-15',
#   'goal': 350000.0,
#   'launched': datetime.datetime(2013, 9, 16, 22, 49, 11),
#   'pledged': 16.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 16.0,
#   'usd_pledged_real': 16.0},
#  {'_id': 376621995,
#   'name': 'The Adventures of Billy Buskirk',
#   'category': 'Family',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-10-14',
#   'goal': 750000.0,
#   'launched': datetime.datetime(2017, 8, 15, 19, 49, 31),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 1227415659,
#   'name': 'MY TINSEL TOWN (Canceled)',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-09-13',
#   'goal': 577000.0,
#   'launched': datetime.datetime(2014, 7, 15, 0, 55, 45),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 520101512,
#   'name': 'Moonlight 5 star (Canceled)',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-06-18',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2016, 4, 19, 6, 41, 47),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1256627633,
#   'name': 'Dangerous Seas: A Beautiful Under Water War App (Canceled)',
#   'category': 'Mobile Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-06-26',
#   'goal': 400000.0,
#   'launched': datetime.datetime(2016, 5, 27, 17, 52, 3),
#   'pledged': 146.0,
#   'state': 'canceled',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 146.0,
#   'usd_pledged_real': 146.0},
#  {'_id': 2033979252,
#   'name': 'ViewCoze.com | Cozy viewing from home (Canceled)',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-02-01',
#   'goal': 370000.0,
#   'launched': datetime.datetime(2015, 12, 10, 23, 55, 54),
#   'pledged': 80.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 80.0,
#   'usd_pledged_real': 80.0},
#  {'_id': 1751639331,
#   'name': 'Meet kubo: an electric scooter to carry all your stuff!',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-12-20',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2013, 11, 20, 6, 0, 7),
#   'pledged': 56667.0,
#   'state': 'failed',
#   'backers': 166,
#   'country': 'US',
#   'usd pledged': 56667.0,
#   'usd_pledged_real': 56667.0},
#  {'_id': 1178067412,
#   'name': 'ONEIDNET Social Professional Commercial Corporate Platform',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-03-24',
#   'goal': 545539.0,
#   'launched': datetime.datetime(2017, 2, 22, 19, 24, 24),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 499583381,
#   'name': 'The Scariest Movie Ever Created',
#   'category': 'Horror',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-08-22',
#   'goal': 100000000.0,
#   'launched': datetime.datetime(2015, 7, 23, 21, 44, 2),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 290390319,
#   'name': 'The SEED Project',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-01-17',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2012, 12, 18, 23, 1, 12),
#   'pledged': 35.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': 1560972255,
#   'name': 'NewsRadio Season 6 (Canceled)',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-12-16',
#   'goal': 3000000.0,
#   'launched': datetime.datetime(2015, 10, 17, 0, 40, 32),
#   'pledged': 101.0,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 101.0,
#   'usd_pledged_real': 101.0},
#  {'_id': 1876072493,
#   'name': 'Get Me Me Kids (Books, Music, Film & Games)',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2015-10-10',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2015, 9, 10, 22, 58, 39),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1517530930,
#   'name': "Daniel's Dream",
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-06-21',
#   'goal': 2000000.0,
#   'launched': datetime.datetime(2013, 5, 22, 22, 2, 9),
#   'pledged': 60.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 60.0,
#   'usd_pledged_real': 60.0},
#  {'_id': 658943325,
#   'name': 'iFly Hand Held Camera Crane- pan AND tilt - iPhone GoPro etc',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2012-12-16',
#   'goal': 444000.0,
#   'launched': datetime.datetime(2012, 11, 5, 19, 5, 56),
#   'pledged': 3439.0,
#   'state': 'failed',
#   'backers': 11,
#   'country': 'US',
#   'usd pledged': 3439.0,
#   'usd_pledged_real': 3439.0},
#  {'_id': 420095150,
#   'name': 'GolferVox',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-07-23',
#   'goal': 1200000.0,
#   'launched': datetime.datetime(2015, 6, 23, 21, 12, 43),
#   'pledged': 70.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 70.0,
#   'usd_pledged_real': 70.0},
#  {'_id': 668413973,
#   'name': 'Power Rangers | fan film reboot movie',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-02-06',
#   'goal': 400000.0,
#   'launched': datetime.datetime(2015, 12, 8, 21, 34, 39),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1481048815,
#   'name': '"Another Network" Film Project',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-05-15',
#   'goal': 225000.0,
#   'launched': datetime.datetime(2014, 3, 31, 22, 46, 31),
#   'pledged': 55.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 55.0,
#   'usd_pledged_real': 55.0},
#  {'_id': 1916952451,
#   'name': 'SELF-SUSTAINING ORGANIC FARM',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-12-09',
#   'goal': 450000.0,
#   'launched': datetime.datetime(2014, 10, 10, 17, 48, 13),
#   'pledged': 11.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 11.0,
#   'usd_pledged_real': 11.0},
#  {'_id': 1554575493,
#   'name': 'Fuel-X-Tender',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-07-31',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2014, 7, 1, 4, 18, 43),
#   'pledged': 272.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 272.0,
#   'usd_pledged_real': 272.0},
#  {'_id': 1601085300,
#   'name': 'Salad Barr ( the new fast food restaurant )',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-03-26',
#   'goal': 270000.0,
#   'launched': datetime.datetime(2016, 2, 26, 0, 4, 18),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 1636574067,
#   'name': 'We want your money (Suspended)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-08-03',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2016, 6, 4, 16, 51, 18),
#   'pledged': 123.0,
#   'state': 'suspended',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 123.0,
#   'usd_pledged_real': 123.0},
#  {'_id': 773987836,
#   'name': "Dutch's Kegs",
#   'category': 'Small Batch',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-12-22',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2015, 11, 17, 23, 36, 6),
#   'pledged': 260.0,
#   'state': 'failed',
#   'backers': 17,
#   'country': 'US',
#   'usd pledged': 260.0,
#   'usd_pledged_real': 260.0},
#  {'_id': 1831435950,
#   'name': 'Pro Tailgater Party Plate',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-05-31',
#   'goal': 365000.0,
#   'launched': datetime.datetime(2017, 4, 25, 21, 25, 17),
#   'pledged': 200.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 200.0},
#  {'_id': 178255149,
#   'name': 'Gabriel Device - Free energy for everyone',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-12-14',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2017, 11, 14, 1, 35, 25),
#   'pledged': 81.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 40.0,
#   'usd_pledged_real': 81.0},
#  {'_id': 1098261281,
#   'name': 'Pallet Wars, Part 1...Two More Weeks and Billions Are Ours!!',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-11-30',
#   'goal': 875000.0,
#   'launched': datetime.datetime(2017, 10, 31, 6, 35, 30),
#   'pledged': 5.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 5.0},
#  {'_id': 849179016,
#   'name': 'Fast Easy Lightweight Modular Cabinets PhastPhurniture',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-04-25',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2017, 3, 11, 3, 10, 44),
#   'pledged': 710.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 200.0,
#   'usd_pledged_real': 710.0},
#  {'_id': 1855118124,
#   'name': 'Sonic Chao World fan game (Canceled)',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-02-14',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2015, 1, 15, 23, 33, 34),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 607916149,
#   'name': 'The Darkest Dawn',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-06-28',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2013, 5, 29, 4, 48, 42),
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'_id': 696960534,
#   'name': 'Adventure Combat Ops - A real life, apocalyptic video game!',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-07-24',
#   'goal': 400000.0,
#   'launched': datetime.datetime(2014, 6, 24, 1, 26, 37),
#   'pledged': 320.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 320.0,
#   'usd_pledged_real': 320.0},
#  {'_id': 2053440575,
#   'name': "World's First Smart Football",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-05-03',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2015, 4, 3, 1, 17, 58),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 397353040,
#   'name': 'The Maryanne Godboldo Story (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-07-20',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2013, 6, 20, 1, 17, 50),
#   'pledged': 2350.0,
#   'state': 'canceled',
#   'backers': 45,
#   'country': 'US',
#   'usd pledged': 2350.0,
#   'usd_pledged_real': 2350.0},
#  {'_id': 534082236,
#   'name': 'M.A.C.S. (Canceled)',
#   'category': 'Space Exploration',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-12-08',
#   'goal': 400000.0,
#   'launched': datetime.datetime(2014, 10, 24, 20, 53, 50),
#   'pledged': 8.0,
#   'state': 'canceled',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 8.0,
#   'usd_pledged_real': 8.0},
#  {'_id': 1957695328,
#   'name': 'Planetary Annihilation - A Next Generation RTS',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-09-14',
#   'goal': 900000.0,
#   'launched': datetime.datetime(2012, 8, 15, 21, 20, 10),
#   'pledged': 2229344.36,
#   'state': 'successful',
#   'backers': 44162,
#   'country': 'US',
#   'usd pledged': 2229344.36,
#   'usd_pledged_real': 2229344.36},
#  {'_id': 1618218442,
#   'name': "Pontruff's Pop Shop, Pizza, and Punk Rock",
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-09-26',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2014, 7, 28, 9, 5, 22),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1402370273,
#   'name': 'The Good Fight of Faith',
#   'category': 'Family',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-11-19',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2015, 10, 20, 0, 56, 49),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 410651072,
#   'name': 'Film Adaptation of "The Traveler"',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-10-31',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2016, 10, 1, 19, 42, 33),
#   'pledged': 25.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 25.0},
#  {'_id': 489938719,
#   'name': 'Uncommon Wealth',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-11-24',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2013, 9, 25, 18, 39, 9),
#   'pledged': 2110.0,
#   'state': 'failed',
#   'backers': 18,
#   'country': 'US',
#   'usd pledged': 2110.0,
#   'usd_pledged_real': 2110.0},
#  {'_id': 1730464042,
#   'name': 'Design the Starship Enterprise Science Research Mock Up',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-12-02',
#   'goal': 313550.0,
#   'launched': datetime.datetime(2013, 10, 18, 9, 18, 13),
#   'pledged': 31.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 31.0,
#   'usd_pledged_real': 31.0},
#  {'_id': 1517172285,
#   'name': 'Backyard Soccer Buddy / Football Mate (Overseas)',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-09-15',
#   'goal': 2000000.0,
#   'launched': datetime.datetime(2016, 7, 20, 18, 37, 9),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1523176093,
#   'name': '"anonymous (street meat)" (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-06-17',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2012, 5, 18, 8, 18, 34),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 934554143,
#   'name': 'Hello Space Boy!',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-07-31',
#   'goal': 2000000.0,
#   'launched': datetime.datetime(2016, 6, 3, 23, 59, 11),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1452500654,
#   'name': 'Interactive Breastfeeding Documentary',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2011-09-20',
#   'goal': 210000.0,
#   'launched': datetime.datetime(2011, 8, 2, 15, 54, 48),
#   'pledged': 12058.3,
#   'state': 'failed',
#   'backers': 117,
#   'country': 'US',
#   'usd pledged': 12058.3,
#   'usd_pledged_real': 12058.3},
#  {'_id': 1783703627,
#   'name': 'Aquaponics system for supplying fresh organic food.',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-06-05',
#   'goal': 8000000.0,
#   'launched': datetime.datetime(2016, 4, 6, 20, 30, 5),
#   'pledged': 21.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 21.0,
#   'usd_pledged_real': 21.0},
#  {'_id': 1028997654,
#   'name': 'After Reset RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-12-11',
#   'goal': 900000.0,
#   'launched': datetime.datetime(2013, 11, 11, 10, 41, 59),
#   'pledged': 47939.0,
#   'state': 'failed',
#   'backers': 1362,
#   'country': 'US',
#   'usd pledged': 47939.0,
#   'usd_pledged_real': 47939.0},
#  {'_id': 731780695,
#   'name': 'SLAYING GIANTS #GOLIATH',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-08-20',
#   'goal': 350000.0,
#   'launched': datetime.datetime(2016, 7, 21, 3, 42, 14),
#   'pledged': 2508.0,
#   'state': 'failed',
#   'backers': 26,
#   'country': 'US',
#   'usd pledged': 175.0,
#   'usd_pledged_real': 2508.0},
#  {'_id': 776004598,
#   'name': 'Fan News',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2015-03-19',
#   'goal': 275000.0,
#   'launched': datetime.datetime(2015, 2, 17, 19, 40, 55),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 580110957,
#   'name': '*FLASHLIFE* Most Complete Emergency Survival Product Ever.',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-11-05',
#   'goal': 350000.0,
#   'launched': datetime.datetime(2016, 9, 21, 20, 21, 50),
#   'pledged': 1865.0,
#   'state': 'failed',
#   'backers': 14,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1865.0},
#  {'_id': 644614031,
#   'name': "Iota: Never lose sight of what's important.",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-14',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2014, 7, 15, 8, 19, 5),
#   'pledged': 282155.0,
#   'state': 'successful',
#   'backers': 1657,
#   'country': 'US',
#   'usd pledged': 282155.0,
#   'usd_pledged_real': 282155.0},
#  {'_id': 281465042,
#   'name': 'RHN - THE REAL HIP-HOP NETWORK TV CHANNEL  DOCUMENTARY',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-06-15',
#   'goal': 2000000.0,
#   'launched': datetime.datetime(2014, 5, 1, 20, 1, 10),
#   'pledged': 225.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 225.0,
#   'usd_pledged_real': 225.0},
#  {'_id': 588787421,
#   'name': 'jfg76tukv u',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2015-12-31',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2015, 11, 19, 16, 47, 3),
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 742934297,
#   'name': 'Shaft in Asia Featured Film',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-10-13',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2015, 8, 14, 22, 56, 40),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 715019941,
#   'name': 'P.U.R.E. Gamers',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-10-04',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2015, 8, 6, 22, 22),
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': 818541249,
#   'name': 'The Hawaiian Girl Art Studio (Canceled)',
#   'category': 'Digital Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2016-03-24',
#   'goal': 1100000.0,
#   'launched': datetime.datetime(2016, 1, 26, 5, 48, 5),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1051776765,
#   'name': 'Independent Broadcasting Company',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-05-31',
#   'goal': 700000.0,
#   'launched': datetime.datetime(2017, 4, 1, 2, 34, 51),
#   'pledged': 56.0,
#   'state': 'canceled',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 56.0,
#   'usd_pledged_real': 56.0},
#  {'_id': 595664945,
#   'name': 'Forbidden Woods (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-08-18',
#   'goal': 2300000.0,
#   'launched': datetime.datetime(2012, 7, 19, 21, 12, 51),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 788197692,
#   'name': 'The Guilt Free Life',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-08-27',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2014, 6, 28, 22, 5, 3),
#   'pledged': 20.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 20.0,
#   'usd_pledged_real': 20.0},
#  {'_id': 1254965074,
#   'name': 'Mayacama Chocolate-Bean-to-Bar Craft Chocolate, Napa,Ca',
#   'category': 'Small Batch',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-04-19',
#   'goal': 780000.0,
#   'launched': datetime.datetime(2015, 2, 18, 17, 23, 50),
#   'pledged': 267.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 267.0,
#   'usd_pledged_real': 267.0},
#  {'_id': 178418310,
#   'name': 'Puzzle Camp',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-06-18',
#   'goal': 750000.0,
#   'launched': datetime.datetime(2014, 5, 19, 3, 56, 46),
#   'pledged': 35.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': 1473597203,
#   'name': 'Vehroot Shelf | Use Your Phone or Tablet as Your Car Stereo',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2018-01-11',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2017, 12, 12, 18, 46, 26),
#   'pledged': 5651.0,
#   'state': 'live',
#   'backers': 14,
#   'country': 'US',
#   'usd pledged': 1248.0,
#   'usd_pledged_real': 5651.0},
#  {'_id': 715203303,
#   'name': "THE YING YANG MURDER MYSTERY'S (Canceled)",
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-12-31',
#   'goal': 900000.0,
#   'launched': datetime.datetime(2014, 12, 1, 23, 50, 57),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 374403417,
#   'name': 'Montgomery Al Concert 5FDP and VOLBEAT',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2014-07-24',
#   'goal': 1040000.0,
#   'launched': datetime.datetime(2014, 6, 24, 2, 58, 50),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1935538858,
#   'name': 'Wall Scaler',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-04-17',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2017, 3, 3, 21, 30, 39),
#   'pledged': 1.0,
#   'state': 'suspended',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 1926637288,
#   'name': 'Historic B&B with an in-house French Bakery in Memphis, TN',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-07-23',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2016, 6, 23, 1, 13, 20),
#   'pledged': 10100.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 10100.0,
#   'usd_pledged_real': 10100.0},
#  {'_id': 1715597415,
#   'name': 'Angelz Landing the Movie',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-02-17',
#   'goal': 1200000.0,
#   'launched': datetime.datetime(2014, 1, 13, 19, 8, 9),
#   'pledged': 356.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 356.0,
#   'usd_pledged_real': 356.0},
#  {'_id': 779336498,
#   'name': 'Morrison Land',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-07-27',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2014, 5, 28, 19, 42, 35),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 1934580784,
#   'name': 'Triple Espresso Goes to The Big Apple',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2013-03-16',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2013, 2, 9, 21, 1, 57),
#   'pledged': 27581.0,
#   'state': 'failed',
#   'backers': 116,
#   'country': 'US',
#   'usd pledged': 27581.0,
#   'usd_pledged_real': 27581.0},
#  {'_id': 1596314651,
#   'name': 'Take And Seek the Movie',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-09-16',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2013, 8, 16, 4, 59, 36),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1834526569,
#   'name': 'Unsung Story: Tale of the Guardians',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-02-15',
#   'goal': 600000.0,
#   'launched': datetime.datetime(2014, 1, 14, 19, 3, 30),
#   'pledged': 660126.51,
#   'state': 'successful',
#   'backers': 15824,
#   'country': 'US',
#   'usd pledged': 660126.51,
#   'usd_pledged_real': 660126.51},
#  {'_id': 2007557271,
#   'name': 'Harishwar Center for Arts, Spirituality & Sustainability',
#   'category': 'Architecture',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-02-03',
#   'goal': 1800000.0,
#   'launched': datetime.datetime(2016, 1, 4, 20, 26, 57),
#   'pledged': 614.0,
#   'state': 'failed',
#   'backers': 14,
#   'country': 'US',
#   'usd pledged': 614.0,
#   'usd_pledged_real': 614.0},
#  {'_id': 695668947,
#   'name': "The Cancer Patient's Film Project",
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-08-17',
#   'goal': 1500000.0,
#   'launched': datetime.datetime(2013, 7, 12, 2, 38, 19),
#   'pledged': 275.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 275.0,
#   'usd_pledged_real': 275.0},
#  {'_id': 832080779,
#   'name': "Small Change: Kids' Financial Life Skills",
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-11',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2014, 7, 17, 15, 54, 12),
#   'pledged': 3536.0,
#   'state': 'failed',
#   'backers': 39,
#   'country': 'US',
#   'usd pledged': 3536.0,
#   'usd_pledged_real': 3536.0},
#  {'_id': 1656648684,
#   'name': 'Save the Williamsburg',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2015-10-27',
#   'goal': 40000000.0,
#   'launched': datetime.datetime(2015, 9, 27, 15, 8, 5),
#   'pledged': 21700.0,
#   'state': 'failed',
#   'backers': 15,
#   'country': 'US',
#   'usd pledged': 21700.0,
#   'usd_pledged_real': 21700.0},
#  {'_id': 256448010,
#   'name': 'Nephilim, Nazis and the New World Order',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-07-12',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2015, 5, 13, 3, 45, 32),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 978588144,
#   'name': 'War At Home',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-11-28',
#   'goal': 340000.0,
#   'launched': datetime.datetime(2015, 10, 29, 16, 0, 52),
#   'pledged': 19328.0,
#   'state': 'failed',
#   'backers': 273,
#   'country': 'US',
#   'usd pledged': 19328.0,
#   'usd_pledged_real': 19328.0},
#  {'_id': 208391519,
#   'name': 'North East',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-07-23',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2017, 5, 24, 0, 17, 26),
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 2.0},
#  {'_id': 1789241689,
#   'name': 'The Great Pyramid, Project USA',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-01',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2014, 6, 2, 15, 53, 58),
#   'pledged': 35.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 35.0,
#   'usd_pledged_real': 35.0},
#  {'_id': 2126842880,
#   'name': 'Time travel app',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-10-09',
#   'goal': 375000.0,
#   'launched': datetime.datetime(2017, 9, 12, 21, 6, 34),
#   'pledged': 135.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 135.0},
#  {'_id': 1046230768,
#   'name': 'Honolulu Haze (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-07-07',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2013, 5, 8, 18, 0, 16),
#   'pledged': 70.0,
#   'state': 'canceled',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 70.0,
#   'usd_pledged_real': 70.0},
#  {'_id': 2135350794,
#   'name': 'Motor Sports Mailboxes',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2015-01-18',
#   'goal': 600000.0,
#   'launched': datetime.datetime(2014, 11, 19, 20, 20, 55),
#   'pledged': 200.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 200.0,
#   'usd_pledged_real': 200.0},
#  {'_id': 381953552,
#   'name': 'Patented MoveNetic Lock - New Post 9-11 Locking Method',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-10-08',
#   'goal': 350000.0,
#   'launched': datetime.datetime(2014, 9, 3, 1, 33, 36),
#   'pledged': 60.0,
#   'state': 'canceled',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 60.0,
#   'usd_pledged_real': 60.0},
#  {'_id': 749406436,
#   'name': 'Hoverboard: The Next Evolution in Personal Electric Mobility',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-10-22',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2015, 9, 17, 16, 39, 3),
#   'pledged': 257275.0,
#   'state': 'failed',
#   'backers': 239,
#   'country': 'US',
#   'usd pledged': 257275.0,
#   'usd_pledged_real': 257275.0},
#  {'_id': 1812682282,
#   'name': 'Make A South African Feature Film! (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2011-12-31',
#   'goal': 2500000.0,
#   'launched': datetime.datetime(2011, 12, 5, 17, 22, 45),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 892520897,
#   'name': 'Feature-Length Movie: Secret of the Missing Grave',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-07-02',
#   'goal': 10000000.0,
#   'launched': datetime.datetime(2013, 5, 3, 23, 15, 16),
#   'pledged': 11975.0,
#   'state': 'failed',
#   'backers': 24,
#   'country': 'US',
#   'usd pledged': 11975.0,
#   'usd_pledged_real': 11975.0},
#  {'_id': 396599619,
#   'name': "Hey Chicago  It's all about you!",
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-10-01',
#   'goal': 380000.0,
#   'launched': datetime.datetime(2015, 8, 17, 9, 43, 37),
#   'pledged': 950.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'US',
#   'usd pledged': 950.0,
#   'usd_pledged_real': 950.0},
#  {'_id': 2028395602,
#   'name': 'All Points Bulletin (APB): Vendetta',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-05-01',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2013, 3, 27, 4, 5, 39),
#   'pledged': 27614.0,
#   'state': 'failed',
#   'backers': 161,
#   'country': 'US',
#   'usd pledged': 27614.0,
#   'usd_pledged_real': 27614.0},
#  {'_id': 233857280,
#   'name': 'As Cine On TV',
#   'category': 'Translations',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2017-04-29',
#   'goal': 2000000.0,
#   'launched': datetime.datetime(2017, 3, 30, 5, 36, 14),
#   'pledged': 192.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 50.0,
#   'usd_pledged_real': 192.0},
#  {'_id': 1489384109,
#   'name': 'The Hendrix Keg - Carbonated, Fresh, Craft Beer on Tap',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-10-15',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2017, 8, 16, 15, 47, 26),
#   'pledged': 48307.0,
#   'state': 'canceled',
#   'backers': 325,
#   'country': 'US',
#   'usd pledged': 9302.0,
#   'usd_pledged_real': 48307.0},
#  {'_id': 515152452,
#   'name': 'Love Gives Hope Art Gallery for Cultural Diversity!',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2017-09-12',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2017, 8, 13, 23, 22, 40),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 549303222,
#   'name': 'The "Get Home Now" Device',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-11-14',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2014, 9, 30, 19, 45, 59),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 599813105,
#   'name': 'In Pursuit of Passion - Travel Television Series',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-06-06',
#   'goal': 280000.0,
#   'launched': datetime.datetime(2016, 5, 7, 0, 56, 56),
#   'pledged': 100.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 100.0,
#   'usd_pledged_real': 100.0},
#  {'_id': 1327325648,
#   'name': 'Welcome to the Wonderful World of AIDS',
#   'category': 'Thrillers',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-11-26',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2014, 10, 27, 4, 27, 59),
#   'pledged': 2827.0,
#   'state': 'failed',
#   'backers': 24,
#   'country': 'US',
#   'usd pledged': 2827.0,
#   'usd_pledged_real': 2827.0},
#  {'_id': 35012487,
#   'name': 'The Homeless art Studio (pic from AP) FUCKING HELP OUT',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2016-03-21',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2016, 1, 21, 23, 34, 11),
#   'pledged': 116.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 116.0,
#   'usd_pledged_real': 116.0},
#  {'_id': 1109856918,
#   'name': 'From Dawson to Jackson Vineyards',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-10-02',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2014, 9, 2, 23, 28, 18),
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': 925988701,
#   'name': 'Art Story',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-08-23',
#   'goal': 350000.0,
#   'launched': datetime.datetime(2013, 7, 7, 23, 34, 52),
#   'pledged': 365670.0,
#   'state': 'successful',
#   'backers': 1785,
#   'country': 'US',
#   'usd pledged': 365670.0,
#   'usd_pledged_real': 365670.0},
#  {'_id': 918134505,
#   'name': 'My a MAZING Academic Profile',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-20',
#   'goal': 2852666.0,
#   'launched': datetime.datetime(2014, 7, 21, 22, 13, 47),
#   'pledged': 130.0,
#   'state': 'failed',
#   'backers': 5,
#   'country': 'US',
#   'usd pledged': 130.0,
#   'usd_pledged_real': 130.0},
#  {'_id': 1254826758,
#   'name': 'The Hill (Canceled)',
#   'category': 'Festivals',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2014-11-12',
#   'goal': 1575000.0,
#   'launched': datetime.datetime(2014, 9, 22, 22, 23, 33),
#   'pledged': 203.0,
#   'state': 'canceled',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 203.0,
#   'usd_pledged_real': 203.0},
#  {'_id': 12584764,
#   'name': 'Sports Cards Unlimited (Canceled)',
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-11-15',
#   'goal': 400000.0,
#   'launched': datetime.datetime(2015, 10, 16, 21, 19),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 222813661,
#   'name': 'Pushup Extreme. (Canceled)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-06-27',
#   'goal': 215000.0,
#   'launched': datetime.datetime(2013, 5, 22, 3, 38, 2),
#   'pledged': 9748.0,
#   'state': 'canceled',
#   'backers': 88,
#   'country': 'US',
#   'usd pledged': 9748.0,
#   'usd_pledged_real': 9748.0},
#  {'_id': 660545998,
#   'name': 'Everyday Dreamers Living in the Beautiful Struggle',
#   'category': 'Hip-Hop',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2017-02-14',
#   'goal': 3500000.0,
#   'launched': datetime.datetime(2016, 12, 16, 0, 59, 57),
#   'pledged': 11.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 11.0},
#  {'_id': 1661242136,
#   'name': 'Top Side Dinner Show! Eat, watch, party, and always enjoy!',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-10-13',
#   'goal': 425000.0,
#   'launched': datetime.datetime(2015, 9, 13, 22, 35, 58),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 263103673,
#   'name': 'The Real Kratos - Epic Action Film',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-08-23',
#   'goal': 295000.0,
#   'launched': datetime.datetime(2013, 7, 24, 22, 59, 49),
#   'pledged': 251.0,
#   'state': 'failed',
#   'backers': 9,
#   'country': 'US',
#   'usd pledged': 251.0,
#   'usd_pledged_real': 251.0},
#  {'_id': 842423920,
#   'name': 'My Russian Kitchen: Love Story',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2013-10-15',
#   'goal': 495000.0,
#   'launched': datetime.datetime(2013, 9, 12, 14, 45, 6),
#   'pledged': 150.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 150.0,
#   'usd_pledged_real': 150.0},
#  {'_id': 34885030,
#   'name': 'The Fuffr Touch Case ï¿½ Multitouch Outside Your Smartphone',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-12-12',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2014, 11, 19, 21, 43, 41),
#   'pledged': 11883.0,
#   'state': 'canceled',
#   'backers': 145,
#   'country': 'US',
#   'usd pledged': 11883.0,
#   'usd_pledged_real': 11883.0},
#  {'_id': 335611499,
#   'name': "Joe N'Mo To Go!",
#   'category': 'Food Trucks',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-09-02',
#   'goal': 400000.0,
#   'launched': datetime.datetime(2016, 7, 4, 3, 8, 12),
#   'pledged': 15.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 15.0},
#  {'_id': 1368984045,
#   'name': 'Japanese Fighting Fish & Japanese Fighting Fish Hold Em',
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-03-26',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2015, 1, 25, 4, 36, 28),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 10.0,
# ...
#   'pledged': 539767.64,
#   'state': 'successful',
#   'backers': 10809,
#   'country': 'US',
#   'usd pledged': 539767.64,
#   'usd_pledged_real': 539767.64},
#  {'_id': 59578124,
#   'name': 'Oregon Ducks.  A Love Story (Canceled)',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-02-04',
#   'goal': 1200000.0,
#   'launched': datetime.datetime(2015, 1, 5, 18, 52, 38),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 450099426,
#   'name': 'The Everyday Backpack, Tote, and Sling',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-09-10',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2016, 7, 13, 0, 47, 35),
#   'pledged': 6565782.5,
#   'state': 'successful',
#   'backers': 26359,
#   'country': 'US',
#   'usd pledged': 1462611.0,
#   'usd_pledged_real': 6565782.5},
#  {'_id': 589134624,
#   'name': 'EXFYRE!!! THE FIRE EXTINGUISHER THAT NO OTHER CAN COMPARE.',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-05-19',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2017, 4, 19, 0, 9, 53),
#   'pledged': 350.0,
#   'state': 'canceled',
#   'backers': 6,
#   'country': 'US',
#   'usd pledged': 375.0,
#   'usd_pledged_real': 350.0},
#  {'_id': 327759503,
#   'name': 'Kuthoomi App',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-05-04',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2017, 3, 5, 4, 5, 43),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 290992626,
#   'name': 'DrYvr- A feature length horror/thriller film',
#   'category': 'Horror',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-02-18',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2017, 1, 19, 18, 12, 53),
#   'pledged': 5630.0,
#   'state': 'failed',
#   'backers': 16,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 5630.0},
#  {'_id': 2085817124,
#   'name': 'Sidemen: Long Road To Glory - Narrated by Marc Maron',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-03-01',
#   'goal': 225000.0,
#   'launched': datetime.datetime(2017, 1, 30, 12, 30, 25),
#   'pledged': 227990.0,
#   'state': 'successful',
#   'backers': 1802,
#   'country': 'US',
#   'usd pledged': 2110.0,
#   'usd_pledged_real': 227990.0},
#  {'_id': 966218871,
#   'name': 'BUILDING BRIDGES - Film Based on a True Story (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-01-06',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2013, 11, 22, 0, 12, 17),
#   'pledged': 44457.49,
#   'state': 'canceled',
#   'backers': 313,
#   'country': 'US',
#   'usd pledged': 44457.49,
#   'usd_pledged_real': 44457.49},
#  {'_id': 410903891,
#   'name': 'Lets Build/Buy a house (Canceled)',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2014-08-29',
#   'goal': 350000.0,
#   'launched': datetime.datetime(2014, 7, 10, 15, 14, 54),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 854061770,
#   'name': 'CARE365',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-03-11',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2017, 2, 9, 2, 54, 14),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 14153312,
#   'name': 'Shin Do Kumat? - Return of Ancient Ones',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-03-26',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2013, 2, 22, 22, 58, 16),
#   'pledged': 565.0,
#   'state': 'failed',
#   'backers': 12,
#   'country': 'US',
#   'usd pledged': 565.0,
#   'usd_pledged_real': 565.0},
#  {'_id': 550427733,
#   'name': '[Project: Monolith]',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-10-10',
#   'goal': 225000.0,
#   'launched': datetime.datetime(2013, 9, 10, 23, 20, 54),
#   'pledged': 4252.0,
#   'state': 'failed',
#   'backers': 147,
#   'country': 'US',
#   'usd pledged': 4252.0,
#   'usd_pledged_real': 4252.0},
#  {'_id': 1961843179,
#   'name': 'Tha Life',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-12-30',
#   'goal': 1500000.0,
#   'launched': datetime.datetime(2016, 11, 30, 8, 45, 41),
#   'pledged': 84.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 84.0},
#  {'_id': 1849686194,
#   'name': 'Kvits - Technology that Improves Dining',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-05-31',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2016, 4, 1, 3, 7, 50),
#   'pledged': 5116.0,
#   'state': 'failed',
#   'backers': 12,
#   'country': 'US',
#   'usd pledged': 5116.0,
#   'usd_pledged_real': 5116.0},
#  {'_id': 552518984,
#   'name': "World's 1st,,Finest ARTISAN Crafted water waits for you.",
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-09-30',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2014, 9, 2, 22, 43, 44),
#   'pledged': 25.0,
#   'state': 'canceled',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'_id': 1974395971,
#   'name': '21st CENTURY MEDICAL PRACTICE SYSTEM THAT CHANGES THE WORLD',
#   'category': 'Makerspaces',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-05-30',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2017, 3, 31, 17, 25, 35),
#   'pledged': 10000.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 10000.0},
#  {'_id': 1680732192,
#   'name': 'The Journal Library',
#   'category': 'Print',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2015-11-20',
#   'goal': 6000000.0,
#   'launched': datetime.datetime(2015, 9, 23, 18, 6, 43),
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'_id': 582572974,
#   'name': 'THE MESSAGE',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-10-18',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2012, 9, 18, 23, 33, 9),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1719494931,
#   'name': 'Obduction',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-11-16',
#   'goal': 1100000.0,
#   'launched': datetime.datetime(2013, 10, 17, 15, 6, 31),
#   'pledged': 1321306.44,
#   'state': 'successful',
#   'backers': 22195,
#   'country': 'US',
#   'usd pledged': 1321306.44,
#   'usd_pledged_real': 1321306.44},
#  {'_id': 1438575969,
#   'name': 'Aviation Brewing Company',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-07-27',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2016, 6, 27, 23, 32, 32),
#   'pledged': 403.0,
#   'state': 'canceled',
#   'backers': 8,
#   'country': 'US',
#   'usd pledged': 403.0,
#   'usd_pledged_real': 403.0},
#  {'_id': 1541349553,
#   'name': 'Funding for a 1950s Museum in Tampa Bay (Canceled)',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2015-05-09',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2015, 3, 10, 0, 29, 38),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1515009526,
#   'name': 'Vir-Sec, SecureCommunique with SecureAxcess. Cyber Security',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-07-23',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2015, 6, 23, 13, 50, 7),
#   'pledged': 16560.0,
#   'state': 'failed',
#   'backers': 312,
#   'country': 'US',
#   'usd pledged': 16560.0,
#   'usd_pledged_real': 16560.0},
#  {'_id': 1195383132,
#   'name': 'LifeBox is a global humanitarian effort solving world hunger',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-07-29',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2017, 6, 29, 18, 27, 52),
#   'pledged': 829.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 829.0},
#  {'_id': 1170179197,
#   'name': 'Cushitepedia ï¿½ A free online encyclopedia of Nubian History',
#   'category': 'Literary Journals',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2017-02-12',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2017, 1, 13, 15, 40, 15),
#   'pledged': 100.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 100.0,
#   'usd_pledged_real': 100.0},
#  {'_id': 1806505732,
#   'name': 'Infinity Blade Chronicles',
#   'category': 'Science Fiction',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-09-16',
#   'goal': 480000.0,
#   'launched': datetime.datetime(2014, 8, 19, 10, 20, 16),
#   'pledged': 103598.0,
#   'state': 'failed',
#   'backers': 396,
#   'country': 'US',
#   'usd pledged': 103598.0,
#   'usd_pledged_real': 103598.0},
#  {'_id': 1388717100,
#   'name': 'StreetGodz- Body Enhancing Shoe',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2012-03-02',
#   'goal': 500000.0,
#   'launched': datetime.datetime(2012, 1, 17, 6, 35, 54),
#   'pledged': 310.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 310.0,
#   'usd_pledged_real': 310.0},
#  {'_id': 363567675,
#   'name': '1979 REVOLUTION: Black Friday',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-12-16',
#   'goal': 395000.0,
#   'launched': datetime.datetime(2013, 11, 13, 13, 22, 42),
#   'pledged': 304741.5,
#   'state': 'failed',
#   'backers': 1653,
#   'country': 'US',
#   'usd pledged': 304741.5,
#   'usd_pledged_real': 304741.5},
#  {'_id': 1633892298,
#   'name': 'The Electronic Kids Gym or The Electronic Family Gym',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-03-14',
#   'goal': 850000.0,
#   'launched': datetime.datetime(2015, 1, 13, 21, 19, 5),
#   'pledged': 1051.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 1051.0,
#   'usd_pledged_real': 1051.0},
#  {'_id': 958762838,
#   'name': 'HOWEVER YOU MOVE',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-09-11',
#   'goal': 700000.0,
#   'launched': datetime.datetime(2014, 7, 28, 22, 15, 48),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 1035074261,
#   'name': "Enjoy The Old Children's Home: Historic Preservation",
#   'category': 'Architecture',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-09-05',
#   'goal': 1100000.0,
#   'launched': datetime.datetime(2016, 8, 4, 13, 22, 21),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 472676658,
#   'name': 'Deathfire: Ruins of Nethermore RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-12-07',
#   'goal': 390000.0,
#   'launched': datetime.datetime(2013, 11, 6, 21, 1),
#   'pledged': 204344.55,
#   'state': 'failed',
#   'backers': 3815,
#   'country': 'US',
#   'usd pledged': 204344.55,
#   'usd_pledged_real': 204344.55},
#  {'_id': 1969755768,
#   'name': 'The War On Truth - Documentary',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-08-27',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2015, 7, 28, 21, 58, 30),
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 1.0,
#   'usd_pledged_real': 1.0},
#  {'_id': 1198265112,
#   'name': 'MONSTER FEST (Canceled)',
#   'category': 'Electronic Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2014-02-12',
#   'goal': 225000.0,
#   'launched': datetime.datetime(2014, 1, 13, 22, 10, 16),
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1512058173,
#   'name': 'Oblivion Seed',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-03-19',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2016, 1, 19, 20, 7, 14),
#   'pledged': 3.0,
#   'state': 'failed',
#   'backers': 3,
#   'country': 'US',
#   'usd pledged': 3.0,
#   'usd_pledged_real': 3.0},
#  {'_id': 1105649293,
#   'name': 'DREAD: Book of Lovecraft',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-12-02',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2014, 10, 31, 16, 11, 54),
#   'pledged': 1705.0,
#   'state': 'failed',
#   'backers': 45,
#   'country': 'US',
#   'usd pledged': 1705.0,
#   'usd_pledged_real': 1705.0},
#  {'_id': 726245303,
#   'name': 'The Surrender Movie Project',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-08-03',
#   'goal': 1000000.0,
#   'launched': datetime.datetime(2015, 7, 4, 6, 30, 20),
#   'pledged': 9405.0,
#   'state': 'failed',
#   'backers': 65,
#   'country': 'US',
#   'usd pledged': 9405.0,
#   'usd_pledged_real': 9405.0},
#  {'_id': 1658680433,
#   'name': "Rose and Thistle Cafe'",
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-07-01',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2015, 5, 28, 3, 12, 45),
#   'pledged': 302.0,
#   'state': 'failed',
#   'backers': 2,
#   'country': 'US',
#   'usd pledged': 302.0,
#   'usd_pledged_real': 302.0},
#  {'_id': 263507280,
#   'name': 'The Chronicles Of The Green Mile Club',
#   'category': 'Fiction',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2014-08-27',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2014, 7, 28, 20, 49, 54),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 1137162248,
#   'name': 'No Blood...Just Diamonds...American Woodie in Sierra Leone',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-03-13',
#   'goal': 450000.0,
#   'launched': datetime.datetime(2015, 2, 10, 5, 54, 23),
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'_id': 442458047,
#   'name': 'A Place to Gather Writing Center, LLC',
#   'category': 'Fiction',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2015-03-28',
#   'goal': 300000.0,
#   'launched': datetime.datetime(2015, 2, 26, 5, 16, 22),
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1,
#   'country': 'US',
#   'usd pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'_id': 314138987,
#   'name': 'Choices',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-10-09',
#   'goal': 350000.0,
#   'launched': datetime.datetime(2014, 9, 3, 19, 7, 30),
#   'pledged': 1775.0,
#   'state': 'failed',
#   'backers': 7,
#   'country': 'US',
#   'usd pledged': 1775.0,
#   'usd_pledged_real': 1775.0},
#  {'_id': 263722455,
#   'name': 'Interactive Smart Tables',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-03-16',
#   'goal': 250000.0,
#   'launched': datetime.datetime(2015, 1, 15, 18, 27, 16),
#   'pledged': 27.0,
#   'state': 'failed',
#   'backers': 4,
#   'country': 'US',
#   'usd pledged': 27.0,
#   'usd_pledged_real': 27.0},
#  ...]

# %% [markdown]
# ## Question 6

# %%
# request = collection.aggregate([
#     { '$match': {'name': {'$in': [ 'sport' ]}}}
# ])
# list(request)

import re
projectsWithSportsInName = collection.find({
    'name': re.compile("sport", re.IGNORECASE)
}).count()

projectsWithSportsInName
# Out:
# 502
